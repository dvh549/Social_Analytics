# %%
import pandas as pd

tweets_df = pd.read_csv("../covid_washington_tweets.csv")
tweets_df.head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2056\1750943224.py:3: DtypeWarning: Columns (28) have mixed types. Specify dtype option on import or set low_memory=False.
#   tweets_df = pd.read_csv("../covid_washington_tweets.csv")
#                                                  url  \
# 0  https://twitter.com/dcexaminer/status/16307191...
# 1  https://twitter.com/layla_abouzaid/status/1630...
# 2  https://twitter.com/foxnewspolitics/status/163...
# 3  https://twitter.com/thehill/status/16307185169...
# 4  https://twitter.com/NewsPolitics/status/163071...
#
#                         date  \
# 0  2023-02-28 23:58:49+00:00
# 1  2023-02-28 23:58:18+00:00
# 2  2023-02-28 23:56:27+00:00
# 3  2023-02-28 23:56:06+00:00
# 4  2023-02-28 23:55:58+00:00
#
#                                           rawContent  \
# 0  Newsom ends California COVID-19 state of emerg...
# 1  Question why everybody was making fun of many ...
# 2  FBI director says COVID pandemic 'most likely'...
# ...

# %%
df_new = tweets_df[['date', 'renderedContent', 'user']]
df_new.head()
# Out:
#                         date  \
# 0  2023-02-28 23:58:49+00:00
# 1  2023-02-28 23:58:18+00:00
# 2  2023-02-28 23:56:27+00:00
# 3  2023-02-28 23:56:06+00:00
# 4  2023-02-28 23:55:58+00:00
#
#                                      renderedContent  \
# 0  Newsom ends California COVID-19 state of emerg...
# 1  Question why everybody was making fun of many ...
# 2  FBI director says COVID pandemic 'most likely'...
# 3  Sen. John Barrasso wants Congress debriefed on...
# 4  FBI director says COVID pandemic 'most likely'...
#
#                                   user
# 0       https://twitter.com/dcexaminer
# 1   https://twitter.com/layla_abouzaid
# 2  https://twitter.com/foxnewspolitics
# 3          https://twitter.com/thehill
# 4     https://twitter.com/NewsPolitics

# %%
# for Quote Network

userlist = ['https://twitter.com/MayorBowser',
            'https://twitter.com/thehill',
            'https://twitter.com/atrupar',
            'https://twitter.com/CNN',
            'https://twitter.com/Heerak4Congress',
            'https://twitter.com/thehill', 
            'https://twitter.com/Dsquared75', 
            'https://twitter.com/washingtonpost',
            'https://twitter.com/realDonaldTrump',
            'https://twitter.com/gtconway3d'
           ]
for user in userlist:
    username = user.split('/')[-1]
    user_tweets = df_new[tweets_df['user'] == user]
    
    user_tweets.to_csv(f'{username}_tweets.csv', index=False)
    user_tweets.to_csv(f'{username}_tweets.txt', index=False, sep='\t')

# %%
# for Reply Network

userlist = ['https://twitter.com/realDonaldTrump',
            'https://twitter.com/thehill',
            'https://twitter.com/HajjiADavis',
            'https://twitter.com/diasporaonline',
            'https://twitter.com/aeidinge4',
            'https://twitter.com/DougSloan',
            'https://twitter.com/Aly_Dar8']
for user in userlist:
    username = user.split('/')[-1]
    user_tweets = df_new[df_new['user'] == user]
    
    user_tweets.to_csv(f'{username}_tweets.csv', index=False)
    user_tweets.to_csv(f'{username}_tweets.txt', index=False, sep='\t')
