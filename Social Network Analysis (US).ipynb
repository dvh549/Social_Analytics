# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# %%
covid_ny = pd.read_csv("twitter data scrape/coronavirus_newyork_tweets.csv")
# covid_ny.head() 
x = covid_ny[covid_ny["user"]=="https://twitter.com/BBC"]
x
# Out:
# Empty DataFrame
# Columns: [url, date, rawContent, renderedContent, id, user, replyCount, retweetCount, likeCount, quoteCount, conversationId, lang, source, sourceUrl, sourceLabel, links, media, retweetedTweet, quotedTweet, inReplyToTweetId, inReplyToUser, mentionedUsers, coordinates, place, hashtags, cashtags, card, viewCount, vibe]
# Index: []
#
# [0 rows x 29 columns]

# %%
covid_washington = pd.read_csv("twitter data scrape/covid_washington_tweets.csv")
covid_washington.head()
# Out:
# C:\Users\DVH\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py:3369: DtypeWarning: Columns (28) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                                                  url  \
# 0  https://twitter.com/dcexaminer/status/16307191...
# 1  https://twitter.com/layla_abouzaid/status/1630...
# 2  https://twitter.com/foxnewspolitics/status/163...
# 3  https://twitter.com/thehill/status/16307185169...
# 4  https://twitter.com/NewsPolitics/status/163071...
#
#                         date  \
# 0  2023-02-28 23:58:49+00:00
# 1  2023-02-28 23:58:18+00:00
# 2  2023-02-28 23:56:27+00:00
# 3  2023-02-28 23:56:06+00:00
# 4  2023-02-28 23:55:58+00:00
#
#                                           rawContent  \
# 0  Newsom ends California COVID-19 state of emerg...
# 1  Question why everybody was making fun of many ...
# ...

# %%
coronavirus_ny = pd.read_csv("twitter data scrape/coronavirus_newyork_tweets.csv")
coronavirus_ny.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/glennlux/status/1630709907...
# 1  https://twitter.com/IM4NY/status/1630708504687...
# 2  https://twitter.com/HuffPostEnt/status/1630688...
# 3  https://twitter.com/NTDNews/status/16306867822...
# 4  https://twitter.com/biorxivpreprint/status/163...
#
#                         date  \
# 0  2023-02-28 23:21:53+00:00
# 1  2023-02-28 23:16:19+00:00
# 2  2023-02-28 21:58:41+00:00
# 3  2023-02-28 21:50:00+00:00
# 4  2023-02-28 21:18:32+00:00
#
#                                           rawContent  \
# 0  It dissolved a pandemic-era moratorium on evic...
# 1  @PBSlade @ZaleskiLuke @SpeakerMcCarthy Trump w...
# 2  Guthrie started her morning hosting "Today," b...
# 3  U.S. House Select Subcommittee on the Coronavi...
# 4  Engineered Immunogens to Expose Conserved Epit...
#
#                                      renderedContent                   id  \
# ...

# %%
coronavirus_washington = pd.read_csv("twitter data scrape/coronavirus_washington_tweets.csv")
coronavirus_washington.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/jimfusillibooks/status/163...
# 1  https://twitter.com/jimfusillibooks/status/163...
# 2  https://twitter.com/Swc26keyWendy/status/16307...
# 3  https://twitter.com/RepRobertGarcia/status/163...
# 4  https://twitter.com/cactusapinyona/status/1630...
#
#                         date  \
# 0  2023-02-28 23:17:43+00:00
# 1  2023-02-28 23:17:17+00:00
# 2  2023-02-28 23:16:47+00:00
# 3  2023-02-28 23:09:02+00:00
# 4  2023-02-28 22:19:29+00:00
#
#                                           rawContent  \
# 0  @MarshaBlackburn Not solely responsible.\r\n\r...
# 1  @MarshaBlackburn On February 24, 2020, Trump s...
# 2  Contaminated Wuhan Rice Sample Proves Wuhan La...
# 3  Today was the first hearing for the House Sele...
# 4  @JoeKleinberg1 @VigilantFox @MartyMakary It’s ...
#
#                                      renderedContent                   id  \
# ...

# %% [markdown]
# ## Covid

# %% [markdown]
# ### New York

# %%
quote_graph = nx.DiGraph()

for i in range(len(covid_ny)):
    if type(covid_ny.iloc[i]["quotedTweet"]) == str:
        quote_graph.add_edge(covid_ny.iloc[i]["user"].split("/")[3], covid_ny.iloc[i]["quotedTweet"].split("/")[3])
        
# nx.draw(quote_graph)
# nx.write_gexf(quote_graph, "gephi/us/covid_newyork_quote_network.gexf")

# %%
quoted_betweenness = nx.betweenness_centrality(quote_graph)
quoted_betweenness_desc = dict(sorted(quoted_betweenness.items(), key=lambda item: item[1], reverse=True))
quoted_betweenness_desc
# Out:
# {'MarkLevineNYC': 3.951452063279682e-06,
#  'JoeBorelliNYC': 2.3113706084435205e-06,
#  'CarlinaRivera': 2.2732291792612844e-06,
#  'WalkerBragman': 1.0069337304110386e-06,
#  'celinegounder': 7.933417269905153e-07,
#  'ydanis': 6.407760102615701e-07,
#  'NYSenatorRivera': 3.6615772014946863e-07,
#  'DrJayVarma': 3.5090114847657407e-07,
#  'rontkim': 2.7461829011210147e-07,
#  'JoshuaX1993': 2.2884857509341787e-07,
#  'bradlander': 1.8307886007473432e-07,
#  'richarddblewitt': 1.8307886007473432e-07,
#  'MOREcaucusUFT': 1.6782228840183978e-07,
#  'yuhline': 1.6019400256539253e-07,
#  'jasonhaber': 1.3730914505605074e-07,
#  'OsseChi': 1.3730914505605074e-07,
#  'RyanFieldABC': 1.2968085921960346e-07,
#  'AlexBerenson': 1.0679600171026168e-07,
#  'Craig_A_Spencer': 1.0679600171026168e-07,
#  'KarinesReyes87': 9.916771587381441e-08,
#  'LauraMiers': 9.153943003736716e-08,
#  'SamAntar': 9.153943003736716e-08,
#  'XGirlNYC': 9.153943003736716e-08,
# ...

# %%
quoted_betweenness_cent = pd.DataFrame(list(quoted_betweenness_desc.items())[:10], columns=["User", "Betweenness Centrality"])
quoted_betweenness_cent
# Out:
#               User  Betweenness Centrality
# 0    MarkLevineNYC            3.951452e-06
# 1    JoeBorelliNYC            2.311371e-06
# 2    CarlinaRivera            2.273229e-06
# 3    WalkerBragman            1.006934e-06
# 4    celinegounder            7.933417e-07
# 5           ydanis            6.407760e-07
# 6  NYSenatorRivera            3.661577e-07
# 7       DrJayVarma            3.509011e-07
# 8          rontkim            2.746183e-07
# 9      JoshuaX1993            2.288486e-07

# %%
quoted_closeness = nx.closeness_centrality(quote_graph)
quoted_closeness_desc = dict(sorted(quoted_closeness.items(), key=lambda item: item[1], reverse=True))
quoted_closeness_desc
# Out:
# {'realDonaldTrump': 0.019290448429499257,
#  'NYGovCuomo': 0.01054519781397903,
#  'nytimes': 0.007037585776668746,
#  'thehill': 0.005507397510265268,
#  'nypost': 0.0051410362327392895,
#  'CNN': 0.004978165938864629,
#  'DrEricDing': 0.004620965319655276,
#  'atrupar': 0.004333042212518195,
#  'MarkLevineNYC': 0.004215617223083064,
#  'kylegriffin1': 0.004104803493449782,
#  'AP': 0.0036844978165938864,
#  'JoeBiden': 0.003406113537117904,
#  'NBCNews': 0.0031915701537877346,
#  'katie_honan': 0.0031660915503710267,
#  'POTUS': 0.0031464031257182256,
#  'NYCMayor': 0.002815444725350494,
#  'EricTopol': 0.0027960255680020253,
#  'business': 0.0027415986329979115,
#  'FDNY': 0.0027274162150786553,
#  'ABC7NY': 0.0027174048658764817,
#  'chelsea_wats': 0.0026254453880569027,
#  'ReuvenBlau': 0.0025667151868025233,
#  'ProjectLincoln': 0.002532751091703057,
#  'macfathom': 0.002508340340123139,
#  'fredmogul': 0.002508340340123139,
#  'washingtonpost': 0.002448326055312955,
# ...

# %%
quoted_closeness_cent = pd.DataFrame(list(quoted_closeness_desc.items())[:10], columns=["User", "Closeness Centrality"])
quoted_closeness_cent
# Out:
#               User  Closeness Centrality
# 0  realDonaldTrump              0.019290
# 1       NYGovCuomo              0.010545
# 2          nytimes              0.007038
# 3          thehill              0.005507
# 4           nypost              0.005141
# 5              CNN              0.004978
# 6       DrEricDing              0.004621
# 7          atrupar              0.004333
# 8    MarkLevineNYC              0.004216
# 9     kylegriffin1              0.004105

# %%
quoted_in_degree = nx.in_degree_centrality(quote_graph)
quoted_in_degree_desc = dict(sorted(quoted_in_degree.items(), key=lambda item: item[1], reverse=True))
quoted_in_degree_desc
# Out:
# {'realDonaldTrump': 0.019563318777292574,
#  'NYGovCuomo': 0.010480349344978166,
#  'nytimes': 0.007336244541484716,
#  'thehill': 0.005502183406113537,
#  'nypost': 0.005065502183406114,
#  'CNN': 0.004978165938864628,
#  'MarkLevineNYC': 0.004803493449781659,
#  'atrupar': 0.004279475982532751,
#  'kylegriffin1': 0.004104803493449782,
#  'AP': 0.003668122270742358,
#  'JoeBiden': 0.0034061135371179036,
#  'DrEricDing': 0.0032314410480349344,
#  'NBCNews': 0.0032314410480349344,
#  'POTUS': 0.0031441048034934497,
#  'NYCMayor': 0.0028820960698689954,
#  'business': 0.002707423580786026,
#  'ABC7NY': 0.002707423580786026,
#  'ProjectLincoln': 0.002532751091703057,
#  'NYDailyNews': 0.0024454148471615717,
#  'washingtonpost': 0.0024454148471615717,
#  'EricTopol': 0.002358078602620087,
#  'Acyn': 0.0022707423580786024,
#  'Reuters': 0.002183406113537118,
#  'GovKathyHochul': 0.002096069868995633,
#  'Gothamist': 0.002096069868995633,
#  'ABC': 0.0020087336244541485,
# ...

# %%
quoted_in_degree_cent = pd.DataFrame(list(quoted_in_degree_desc.items())[:10], columns=["User", "In Degree Centrality"])
quoted_in_degree_cent
# Out:
#               User  In Degree Centrality
# 0  realDonaldTrump              0.019563
# 1       NYGovCuomo              0.010480
# 2          nytimes              0.007336
# 3          thehill              0.005502
# 4           nypost              0.005066
# 5              CNN              0.004978
# 6    MarkLevineNYC              0.004803
# 7          atrupar              0.004279
# 8     kylegriffin1              0.004105
# 9               AP              0.003668

# %%
quoted_out_degree = nx.out_degree_centrality(quote_graph)
quoted_out_degree_desc = dict(sorted(quoted_out_degree.items(), key=lambda item: item[1], reverse=True))
quoted_out_degree_desc
# Out:
# {'MerrylWiener': 0.012576419213973799,
#  'DrDiva82': 0.011441048034934497,
#  'Wildfang135': 0.007336244541484716,
#  'watergatesummer': 0.006986899563318777,
#  'AmBeautifulShow': 0.0053275109170305675,
#  'TimFullerton': 0.005240174672489083,
#  'ARaj_Energy': 0.0046288209606986895,
#  'jazza2z': 0.004192139737991266,
#  'TheMrJayBrown': 0.004104803493449782,
#  'jessepstein': 0.003580786026200873,
#  'angeles524': 0.0034934497816593883,
#  'jdny2': 0.0030567685589519646,
#  'JamieP01329606': 0.00296943231441048,
#  'NickyFrank30': 0.002707423580786026,
#  'brunosmom0408': 0.002707423580786026,
#  'JoshuaX1993': 0.0026200873362445414,
#  'librajiminez': 0.0026200873362445414,
#  'lastbohemians': 0.0026200873362445414,
#  'KarlaFisk': 0.0024454148471615717,
#  'drantbradley': 0.0024454148471615717,
#  'AirlineFlyer': 0.002358078602620087,
#  'richmintz': 0.002358078602620087,
#  'CFCCovid': 0.002358078602620087,
#  'Helen_Highly': 0.0022707423580786024,
# ...

# %%
quoted_out_degree_cent = pd.DataFrame(list(quoted_out_degree_desc.items())[:10], columns=["User", "Out Degree Centrality"])
quoted_out_degree_cent
# Out:
#               User  Out Degree Centrality
# 0     MerrylWiener               0.012576
# 1         DrDiva82               0.011441
# 2      Wildfang135               0.007336
# 3  watergatesummer               0.006987
# 4  AmBeautifulShow               0.005328
# 5     TimFullerton               0.005240
# 6      ARaj_Energy               0.004629
# 7          jazza2z               0.004192
# 8    TheMrJayBrown               0.004105
# 9      jessepstein               0.003581

# %%
# No edges to use to create retweet network graph

retweet_sources, retweet_target = [], []

for i in range(len(covid_ny)):
    if type(covid_ny.iloc[i]["retweetedTweet"]) == str:
        retweet_sources.append(covid_ny.iloc[i]["user"].split("/")[3])
        retweet_target.append(covid_ny.iloc[i]["retweetedTweet"].split("/")[3])
        
retweet_sources, retweet_target
# Out:
# ([], [])

# %%
reply_graph = nx.DiGraph()

for i in range(len(covid_ny)):
    if type(covid_ny.iloc[i]["inReplyToUser"]) == str:
        reply_graph.add_edge(covid_ny.iloc[i]["user"].split("/")[3], covid_ny.iloc[i]["inReplyToUser"].split("/")[3])
        
# nx.draw(reply_graph)
# nx.write_gexf(reply_graph, "gephi/us/covid_newyork_reply_network.gexf")

# %%
reply_betweenness = nx.betweenness_centrality(reply_graph)
reply_betweenness_desc = dict(sorted(reply_betweenness.items(), key=lambda item: item[1], reverse=True))
reply_betweenness_desc
# Out:
# {'NickyFrank30': 3.579956336968327e-06,
#  'JoeBorelliNYC': 1.6150178963766888e-06,
#  'AirlineFlyer': 1.535612849804835e-06,
#  'ShabazzStuart': 1.4858164646665536e-06,
#  'chayesmatthew': 1.308164496065118e-06,
#  'VinPickles': 1.2476013249509921e-06,
#  'nyillini311': 1.1830006090959245e-06,
#  'ginavergel7': 1.0699493563495563e-06,
#  'Mezikenyc': 8.869139947601983e-07,
#  'Biedersam': 7.92704617471558e-07,
#  'randimarshall': 6.621573375144424e-07,
#  'ariccio': 4.562425557264146e-07,
#  'SquarePegDem': 4.5220501098547286e-07,
#  'sicksicksickx': 3.014700073236486e-07,
#  'RussOnPolitics': 2.543653186793285e-07,
#  'richmintz': 2.543653186793285e-07,
#  'thetrizzles': 2.5032777393838673e-07,
#  'the_transit_guy': 2.2610250549273643e-07,
#  'MarkLevineNYC': 2.2071911250481413e-07,
#  'brianvan': 2.2071911250481413e-07,
#  'agordonstudio': 2.059147817880278e-07,
#  'CCupo': 1.655393343786106e-07,
#  'watergatesummer': 1.601559413906883e-07,
# ...

# %%
reply_betweenness_cent = pd.DataFrame(list(reply_betweenness_desc.items())[:10], columns=["User", "Betweenness Centrality"])
reply_betweenness_cent
# Out:
#             User  Betweenness Centrality
# 0   NickyFrank30            3.579956e-06
# 1  JoeBorelliNYC            1.615018e-06
# 2   AirlineFlyer            1.535613e-06
# 3  ShabazzStuart            1.485816e-06
# 4  chayesmatthew            1.308164e-06
# 5     VinPickles            1.247601e-06
# 6    nyillini311            1.183001e-06
# 7    ginavergel7            1.069949e-06
# 8      Mezikenyc            8.869140e-07
# 9      Biedersam            7.927046e-07

# %%
reply_closeness = nx.closeness_centrality(reply_graph)
reply_closeness_desc = dict(sorted(reply_closeness.items(), key=lambda item: item[1], reverse=True))
reply_closeness_desc
# Out:
# {'realDonaldTrump': 0.009047335688374913,
#  'NYGovCuomo': 0.004292468665811092,
#  'Jim_Jordan': 0.0020962932294969422,
#  'JoeBiden': 0.0020934580788177044,
#  'NYCMayor': 0.0019083061931295543,
#  'thehill': 0.0019076268388422172,
#  'GOP': 0.0016938653994305337,
#  'DrEricDing': 0.0016656144786905927,
#  'ProjectLincoln': 0.0014341326995052626,
#  'SpeakerMcCarthy': 0.001251156064341859,
#  'nypost': 0.0012472944715506806,
#  'MollyJongFast': 0.001190283794194429,
#  'nytimes': 0.001188598261124766,
#  'tedcruz': 0.0011461624873708956,
#  'POTUS': 0.001138350747654097,
#  'mmpadellan': 0.0011017003558457758,
#  'MarkLevineNYC': 0.0010513186373983677,
#  'CNN': 0.001028406520170708,
#  'atrupar': 0.0009952321162942335,
#  'MarshaBlackburn': 0.0009917635554723464,
#  'nathaliejacoby1': 0.0009904985509373051,
#  'ABC': 0.0009551236026895442,
#  'joncoopertweets': 0.0009551236026895442,
#  'AOC': 0.0008804431563887156,
#  'RepMTG': 0.0008452254301331669,
# ...

# %%
reply_closeness_cent = pd.DataFrame(list(reply_closeness_desc.items())[:10], columns=["User", "Closeness Centrality"])
reply_closeness_cent
# Out:
#               User  Closeness Centrality
# 0  realDonaldTrump              0.009047
# 1       NYGovCuomo              0.004292
# 2       Jim_Jordan              0.002096
# 3         JoeBiden              0.002093
# 4         NYCMayor              0.001908
# 5          thehill              0.001908
# 6              GOP              0.001694
# 7       DrEricDing              0.001666
# 8   ProjectLincoln              0.001434
# 9  SpeakerMcCarthy              0.001251

# %%
reply_in_degree = nx.in_degree_centrality(reply_graph)
reply_in_degree_desc = dict(sorted(reply_in_degree.items(), key=lambda item: item[1], reverse=True))
reply_in_degree_desc
# Out:
# {'realDonaldTrump': 0.009097912616016729,
#  'NYGovCuomo': 0.004292160387394989,
#  'Jim_Jordan': 0.0020910524964232,
#  'JoeBiden': 0.0020910524964232,
#  'thehill': 0.0019076268388422172,
#  'NYCMayor': 0.0019076268388422172,
#  'GOP': 0.0016875160497450384,
#  'ProjectLincoln': 0.001430720129131663,
#  'nypost': 0.0012472944715506804,
#  'SpeakerMcCarthy': 0.0012472944715506804,
#  'nytimes': 0.0011739242085182875,
#  'MollyJongFast': 0.0011739242085182875,
#  'tedcruz': 0.001137239077002091,
#  'POTUS': 0.001137239077002091,
#  'mmpadellan': 0.0011005539454858946,
#  'MarkLevineNYC': 0.001063868813969698,
#  'DrEricDing': 0.0010271836824535016,
#  'CNN': 0.0010271836824535016,
#  'MarshaBlackburn': 0.0009904985509373051,
#  'atrupar': 0.0009904985509373051,
#  'nathaliejacoby1': 0.0009904985509373051,
#  'ABC': 0.0009538134194211086,
#  'joncoopertweets': 0.0009538134194211086,
#  'AOC': 0.0008804431563887156,
#  'SenTedCruz': 0.0008437580248725192,
# ...

# %%
reply_in_degree_cent = pd.DataFrame(list(reply_in_degree_desc.items())[:10], columns=["User", "In Degree Centrality"])
reply_in_degree_cent
# Out:
#               User  In Degree Centrality
# 0  realDonaldTrump              0.009098
# 1       NYGovCuomo              0.004292
# 2       Jim_Jordan              0.002091
# 3         JoeBiden              0.002091
# 4          thehill              0.001908
# 5         NYCMayor              0.001908
# 6              GOP              0.001688
# 7   ProjectLincoln              0.001431
# 8           nypost              0.001247
# 9  SpeakerMcCarthy              0.001247

# %%
reply_out_degree = nx.out_degree_centrality(reply_graph)
reply_out_degree_desc = dict(sorted(reply_out_degree.items(), key=lambda item: item[1], reverse=True))
reply_out_degree_desc
# Out:
# {'IsabelM64995699': 0.007667192486885065,
#  'MisterPatrick1': 0.0060897318316886166,
#  'NickyFrank30': 0.00605304670017242,
#  'ariccio': 0.005466084595913277,
#  'agordonstudio': 0.0050258630177189186,
#  'FanaticalModera': 0.004402215781943579,
#  'watergatesummer': 0.004328845518911185,
#  'Helen_Highly': 0.004108734729814006,
#  'jamieob256': 0.0039253090722330235,
#  'CFCCovid': 0.0033016618364576835,
#  'KarlaFisk': 0.0030081807843281116,
#  'sweetiebabes08': 0.0029714956528119154,
#  'leelaurie22': 0.002861440258263326,
#  'leakservicer': 0.0024945889431013607,
#  'VThack': 0.002347848417036575,
#  'TalksSoMuch': 0.0022377930224879855,
#  'GypsyRN212': 0.0020910524964232,
#  'KevinClamato': 0.002054367364907003,
#  'almighty_red': 0.0019809971018746103,
#  'Buaidh_BhoysHH': 0.0019076268388422172,
#  'chriscegegbara': 0.0019076268388422172,
#  'iammrmeehan': 0.0018709417073260208,
#  'lesliebialler': 0.0018342565758098241,
#  'nyc_nancy': 0.0018342565758098241,
# ...

# %%
reply_out_degree_cent = pd.DataFrame(list(reply_out_degree_desc.items())[:10], columns=["User", "Out Degree Centrality"])
reply_out_degree_cent
# Out:
#               User  Out Degree Centrality
# 0  IsabelM64995699               0.007667
# 1   MisterPatrick1               0.006090
# 2     NickyFrank30               0.006053
# 3          ariccio               0.005466
# 4    agordonstudio               0.005026
# 5  FanaticalModera               0.004402
# 6  watergatesummer               0.004329
# 7     Helen_Highly               0.004109
# 8       jamieob256               0.003925
# 9         CFCCovid               0.003302

# %%
# Reply in-degree / Retweet in-degree (to find out if there are users/tweets that are deeply unpopular due to many replies of disagreement [for high ratios])
# Only use if retweet network can be constructed

# reply_in_degree_cent["In Degree Centrality"] / retweet_in_degree_cent["In Degree Centrality"]

# %% [markdown]
# ### Washington

# %%
quote_graph = nx.DiGraph()

for i in range(len(covid_washington)):
    if type(covid_washington.iloc[i]["quotedTweet"]) == str:
        quote_graph.add_edge(covid_washington.iloc[i]["user"].split("/")[3], covid_washington.iloc[i]["quotedTweet"].split("/")[3])
        
# nx.draw(quote_graph)
# nx.write_gexf(quote_graph, "gephi/us/covid_washington_quote_network.gexf")

# %%
quoted_betweenness = nx.betweenness_centrality(quote_graph)
quoted_betweenness_desc = dict(sorted(quoted_betweenness.items(), key=lambda item: item[1], reverse=True))
quoted_betweenness_desc
# Out:
# {'gtconway3d': 1.276006832519617e-06,
#  'atrupar': 8.999206081980457e-07,
#  'mjs_DC': 8.058990521176528e-07,
#  'AlexCTaliadoros': 5.238343838764744e-07,
#  'ReedReports': 2.014747630294132e-07,
#  'PamKeithFL': 2.014747630294132e-07,
#  'CMLewisGeorgeW4': 1.8804311216078567e-07,
#  'aeidinger': 1.8804311216078567e-07,
#  'davidshepardson': 1.8804311216078567e-07,
#  'MinerPTO': 1.8804311216078567e-07,
#  'councilofdc': 1.8804311216078567e-07,
#  'treeaston': 1.6117981042353057e-07,
#  'DanMulhall': 1.6117981042353057e-07,
#  'JayCarney': 1.6117981042353057e-07,
#  'LawrenceGostin': 1.3431650868627548e-07,
#  'DrPhillipsMD': 1.3431650868627548e-07,
#  'jennaudrey': 1.2088485781764794e-07,
#  'TevonBlair': 1.2088485781764794e-07,
#  'alizaslav': 1.2088485781764794e-07,
#  'MurielBowser': 1.2088485781764794e-07,
#  'wsteaks': 1.2088485781764794e-07,
#  'US_FDA': 1.0745320694902038e-07,
#  'DCWard7teacher': 1.0745320694902038e-07,
#  'PeterHotez': 9.402155608039283e-08,
# ...

# %%
quoted_betweenness_cent = pd.DataFrame(list(quoted_betweenness_desc.items())[:10], columns=["User", "Betweenness Centrality"])
quoted_betweenness_cent
# Out:
#               User  Betweenness Centrality
# 0       gtconway3d            1.276007e-06
# 1          atrupar            8.999206e-07
# 2           mjs_DC            8.058991e-07
# 3  AlexCTaliadoros            5.238344e-07
# 4      ReedReports            2.014748e-07
# 5       PamKeithFL            2.014748e-07
# 6  CMLewisGeorgeW4            1.880431e-07
# 7        aeidinger            1.880431e-07
# 8  davidshepardson            1.880431e-07
# 9         MinerPTO            1.880431e-07

# %%
quoted_closeness = nx.closeness_centrality(quote_graph)
quoted_closeness_desc = dict(sorted(quoted_closeness.items(), key=lambda item: item[1], reverse=True))
quoted_closeness_desc
# Out:
# {'realDonaldTrump': 0.016955143825826788,
#  'thehill': 0.007096057950860008,
#  'MayorBowser': 0.006403287548263792,
#  'washingtonpost': 0.004854665556948556,
#  'CNN': 0.0047736110049486765,
#  'nytimes': 0.004519643064086221,
#  'atrupar': 0.004030896824157164,
#  'JoeBiden': 0.003721301554190649,
#  'Reuters': 0.003620725836509821,
#  'NBCNews': 0.0031289836597519992,
#  'CBSNews': 0.003017234243332285,
#  'ASlavitt': 0.002785776050349002,
#  'DrEricDing': 0.0025495422412794067,
#  'kylegriffin1': 0.0025495422412794067,
#  'AP': 0.0025495422412794067,
#  'fox5dc': 0.0025495422412794067,
#  'revrrlewis': 0.0024928857470287533,
#  'kaitlancollins': 0.0024481399930467032,
#  'NPR': 0.002222031874316637,
#  'DCist': 0.00220739587989559,
#  'ABC': 0.0021294472128867772,
#  'POTUS': 0.0021187401431976096,
#  'MSNBC': 0.002085989106501333,
#  'ProjectLincoln': 0.002085989106501333,
#  'nypost': 0.0019701008228068142,
#  'jaketapper': 0.0018606507770953244,
# ...

# %%
quoted_closeness_cent = pd.DataFrame(list(quoted_closeness_desc.items())[:10], columns=["User", "Closeness Centrality"])
quoted_closeness_cent
# Out:
#               User  Closeness Centrality
# 0  realDonaldTrump              0.016955
# 1          thehill              0.007096
# 2      MayorBowser              0.006403
# 3   washingtonpost              0.004855
# 4              CNN              0.004774
# 5          nytimes              0.004520
# 6          atrupar              0.004031
# 7         JoeBiden              0.003721
# 8          Reuters              0.003621
# 9          NBCNews              0.003129

# %%
quoted_in_degree = nx.in_degree_centrality(quote_graph)
quoted_in_degree_desc = dict(sorted(quoted_in_degree.items(), key=lambda item: item[1], reverse=True))
quoted_in_degree_desc
# Out:
# {'realDonaldTrump': 0.01610847143353807,
#  'thehill': 0.007069185305365627,
#  'MayorBowser': 0.006489743886893035,
#  'washingtonpost': 0.004751419631475257,
#  'CNN': 0.004751419631475257,
#  'nytimes': 0.004519643064086221,
#  'atrupar': 0.004056089929308147,
#  'JoeBiden': 0.0037084250782245913,
#  'Reuters': 0.0035925367945300727,
#  'NBCNews': 0.003128983659751999,
#  'CBSNews': 0.0030130953760574807,
#  'ASlavitt': 0.0027813188086684435,
#  'DrEricDing': 0.0025495422412794063,
#  'kylegriffin1': 0.0025495422412794063,
#  'kaitlancollins': 0.0025495422412794063,
#  'AP': 0.0025495422412794063,
#  'fox5dc': 0.0025495422412794063,
#  'POTUS': 0.0023177656738903696,
#  'NPR': 0.002201877390195851,
#  'DCist': 0.002201877390195851,
#  'ABC': 0.002085989106501333,
#  'MSNBC': 0.002085989106501333,
#  'ProjectLincoln': 0.002085989106501333,
#  'nypost': 0.0019701008228068142,
#  'cnnbrk': 0.0018542125391122957,
#  'jaketapper': 0.0018542125391122957,
# ...

# %%
quoted_in_degree_cent = pd.DataFrame(list(quoted_in_degree_desc.items())[:10], columns=["User", "In Degree Centrality"])
quoted_in_degree_cent
# Out:
#               User  In Degree Centrality
# 0  realDonaldTrump              0.016108
# 1          thehill              0.007069
# 2      MayorBowser              0.006490
# 3   washingtonpost              0.004751
# 4              CNN              0.004751
# 5          nytimes              0.004520
# 6          atrupar              0.004056
# 7         JoeBiden              0.003708
# 8          Reuters              0.003593
# 9          NBCNews              0.003129

# %%
quoted_out_degree = nx.out_degree_centrality(quote_graph)
quoted_out_degree_desc = dict(sorted(quoted_out_degree.items(), key=lambda item: item[1], reverse=True))
quoted_out_degree_desc
# Out:
# {'Heerak4Congress': 0.06524510372001391,
#  'Dsquared75': 0.014370147178120291,
#  'LovelyLassSandy': 0.011588828369451848,
#  'PoeticLicencedk': 0.008228068142310812,
#  'richardmskinner': 0.007416850156449183,
#  'laurenskahn': 0.005678525901031405,
#  'twright55': 0.004635531347780739,
#  'HarlemGirl59': 0.004635531347780739,
#  'SimonWDC': 0.004056089929308147,
#  'JoJobeth328': 0.004056089929308147,
#  'bkogod': 0.0037084250782245913,
#  'LisaNewmannews': 0.0035925367945300727,
#  'toddntucker': 0.003476648510835554,
#  'PositivelyBrie': 0.003476648510835554,
#  'CrynJohannsen': 0.0032448719434465174,
#  'fabucat': 0.003128983659751999,
#  'MrChadClarke': 0.003128983659751999,
#  'laSerenissima20': 0.002897207092362962,
#  'cdorobek': 0.0027813188086684435,
#  'MBilalY': 0.0027813188086684435,
#  'StephMDavisPhD': 0.002665430524973925,
#  'janettewms': 0.002665430524973925,
#  'DougSloan': 0.0025495422412794063,
#  'oktakemypic': 0.0025495422412794063,
# ...

# %%
quoted_out_degree_cent = pd.DataFrame(list(quoted_out_degree_desc.items())[:10], columns=["User", "Out Degree Centrality"])
quoted_out_degree_cent
# Out:
#               User  Out Degree Centrality
# 0  Heerak4Congress               0.065245
# 1       Dsquared75               0.014370
# 2  LovelyLassSandy               0.011589
# 3  PoeticLicencedk               0.008228
# 4  richardmskinner               0.007417
# 5      laurenskahn               0.005679
# 6        twright55               0.004636
# 7     HarlemGirl59               0.004636
# 8         SimonWDC               0.004056
# 9      JoJobeth328               0.004056

# %%
# No edges to use to create retweet network graph

retweet_sources, retweet_target = [], []

for i in range(len(covid_washington)):
    if type(covid_washington.iloc[i]["retweetedTweet"]) == str:
        retweet_sources.append(covid_washington.iloc[i]["user"].split("/")[3])
        retweet_target.append(covid_washington.iloc[i]["retweetedTweet"].split("/")[3])
        
retweet_sources, retweet_target
# Out:
# ([], [])

# %%
reply_graph = nx.DiGraph()

for i in range(len(covid_washington)):
    if type(covid_washington.iloc[i]["inReplyToUser"]) == str:
        reply_graph.add_edge(covid_washington.iloc[i]["user"].split("/")[3], covid_washington.iloc[i]["inReplyToUser"].split("/")[3])
        
# nx.draw(reply_graph)
# nx.write_gexf(reply_graph, "gephi/us/covid_washington_reply_network.gexf")

# %%
reply_betweenness = nx.betweenness_centrality(reply_graph)
reply_betweenness_desc = dict(sorted(reply_betweenness.items(), key=lambda item: item[1], reverse=True))
reply_betweenness_desc
# Out:
# {'aeidinger': 8.588478629534011e-07,
#  'DougSloan': 8.195862463612456e-07,
#  'mattyglesias': 6.527243758445848e-07,
#  'samerfarha': 5.447549302161572e-07,
#  'DCHomos': 4.5150859080978803e-07,
#  'Aly_Dar8': 3.38631443107341e-07,
#  'conorjrogers': 3.239083368852827e-07,
#  'RyanLEllis': 3.190006348112633e-07,
#  'CorieWhalen': 2.7483131614508837e-07,
#  'gerald_joseph90': 2.6992361407106893e-07,
#  'dcborn61': 2.1593889125685513e-07,
#  'jc50000000': 2.1103118918283572e-07,
#  'Tammy': 1.8649267881273854e-07,
#  'JPFinlayNBCS': 1.6195416844264136e-07,
#  'daveschneier': 1.5213876429460248e-07,
#  'LeCountB': 1.4723106222058304e-07,
#  'nathanking': 1.3741565807254418e-07,
#  'EricFidler': 1.276002539245053e-07,
#  'StephMDavisPhD': 1.226925518504859e-07,
#  'ronnietaylor474': 1.1778484977646645e-07,
#  'gtconway3d': 9.81540414803887e-08,
#  'atrupar': 9.324633940636927e-08,
#  'tomsherwood': 8.833863733234983e-08,
#  'marcaross': 7.852323318431096e-08,
# ...

# %%
reply_betweenness_cent = pd.DataFrame(list(reply_betweenness_desc.items())[:10], columns=["User", "Betweenness Centrality"])
reply_betweenness_cent
# Out:
#               User  Betweenness Centrality
# 0        aeidinger            8.588479e-07
# 1        DougSloan            8.195862e-07
# 2     mattyglesias            6.527244e-07
# 3       samerfarha            5.447549e-07
# 4          DCHomos            4.515086e-07
# 5         Aly_Dar8            3.386314e-07
# 6     conorjrogers            3.239083e-07
# 7       RyanLEllis            3.190006e-07
# 8      CorieWhalen            2.748313e-07
# 9  gerald_joseph90            2.699236e-07

# %%
reply_closeness = nx.closeness_centrality(reply_graph)
reply_closeness_desc = dict(sorted(reply_closeness.items(), key=lambda item: item[1], reverse=True))
reply_closeness_desc
# Out:
# {'realDonaldTrump': 0.009799189883209953,
#  'thehill': 0.002171628721541156,
#  'Jim_Jordan': 0.002031523642732049,
#  'GOP': 0.001681260945709282,
#  'CNN': 0.0016682279151223882,
#  'SpeakerMcCarthy': 0.0015411558669001751,
#  'washingtonpost': 0.0014010507880910684,
#  'MollyJongFast': 0.0013343340838962556,
#  'MarshaBlackburn': 0.0013309982486865149,
#  'atrupar': 0.0013309982486865149,
#  'kylegriffin1': 0.0013309982486865149,
#  'nathaliejacoby1': 0.0012609457092819614,
#  'WhiteHouse45': 0.001190893169877408,
#  'chrislhayes': 0.0011838879159369528,
#  'joncoopertweets': 0.0011208406304728546,
#  'NateSilver538': 0.0010549088286803338,
#  'POTUS': 0.0010507880910683013,
#  'DonaldJTrumpJr': 0.0010507880910683013,
#  'mattyglesias': 0.0010507880910683013,
#  'IvankaTrump': 0.0010507880910683013,
#  'RepMTG': 0.0009851138353765324,
#  'funder': 0.0009807355516637478,
#  'SenTedCruz': 0.0009153531815528313,
#  'RadioFreeTom': 0.0009106830122591944,
# ...

# %%
reply_closeness_cent = pd.DataFrame(list(reply_closeness_desc.items())[:10], columns=["User", "Closeness Centrality"])
reply_closeness_cent
# Out:
#               User  Closeness Centrality
# 0  realDonaldTrump              0.009799
# 1          thehill              0.002172
# 2       Jim_Jordan              0.002032
# 3              GOP              0.001681
# 4              CNN              0.001668
# 5  SpeakerMcCarthy              0.001541
# 6   washingtonpost              0.001401
# 7    MollyJongFast              0.001334
# 8  MarshaBlackburn              0.001331
# 9          atrupar              0.001331

# %%
reply_in_degree = nx.in_degree_centrality(reply_graph)
reply_in_degree_desc = dict(sorted(reply_in_degree.items(), key=lambda item: item[1], reverse=True))
reply_in_degree_desc
# Out:
# {'realDonaldTrump': 0.010017513134851138,
#  'thehill': 0.002171628721541156,
#  'Jim_Jordan': 0.002031523642732049,
#  'CNN': 0.0017513134851138354,
#  'GOP': 0.001681260945709282,
#  'SpeakerMcCarthy': 0.0015411558669001751,
#  'washingtonpost': 0.0014010507880910681,
#  'MarshaBlackburn': 0.0013309982486865149,
#  'atrupar': 0.0013309982486865149,
#  'kylegriffin1': 0.0013309982486865149,
#  'MollyJongFast': 0.0013309982486865149,
#  'nathaliejacoby1': 0.0012609457092819614,
#  'WhiteHouse45': 0.001190893169877408,
#  'mattyglesias': 0.0011208406304728546,
#  'joncoopertweets': 0.0011208406304728546,
#  'POTUS': 0.001050788091068301,
#  'DonaldJTrumpJr': 0.001050788091068301,
#  'NateSilver538': 0.001050788091068301,
#  'IvankaTrump': 0.001050788091068301,
#  'RepMTG': 0.0009807355516637478,
#  'funder': 0.0009807355516637478,
#  'SenTedCruz': 0.0009106830122591943,
#  'RadioFreeTom': 0.0009106830122591943,
#  'MayorBowser': 0.0009106830122591943,
# ...

# %%
reply_in_degree_cent = pd.DataFrame(list(reply_in_degree_desc.items())[:10], columns=["User", "In Degree Centrality"])
reply_in_degree_cent
# Out:
#               User  In Degree Centrality
# 0  realDonaldTrump              0.010018
# 1          thehill              0.002172
# 2       Jim_Jordan              0.002032
# 3              CNN              0.001751
# 4              GOP              0.001681
# 5  SpeakerMcCarthy              0.001541
# 6   washingtonpost              0.001401
# 7  MarshaBlackburn              0.001331
# 8          atrupar              0.001331
# 9     kylegriffin1              0.001331

# %%
reply_out_degree = nx.out_degree_centrality(reply_graph)
reply_out_degree_desc = dict(sorted(reply_out_degree.items(), key=lambda item: item[1], reverse=True))
reply_out_degree_desc
# Out:
# {'HajjiADavis': 0.013099824868651489,
#  'diasporaonline': 0.011418563922942207,
#  'fabucat': 0.010367775831873906,
#  'koamac': 0.006024518388791593,
#  'NotoriousRBF': 0.005253940455341506,
#  'VincentDiazJr1': 0.005253940455341506,
#  'Lee4Pete': 0.005183887915936953,
#  'tomsommers1': 0.005183887915936953,
#  'freelancerjourn': 0.004903677758318739,
#  'Aly_Dar8': 0.004903677758318739,
#  'RyanLEllis': 0.004623467600700525,
#  'gsojudy': 0.004133099824868651,
#  'DougSloan': 0.004063047285464098,
#  'Jezzrow22': 0.0036427320490367773,
#  'Harriet86108004': 0.0036427320490367773,
#  'Matthew08408848': 0.003362521891418564,
#  'cefilby': 0.0032924693520140105,
#  'orecule': 0.0032924693520140105,
#  'ReesiePeacie': 0.0031523642732049035,
#  'chuck_dc': 0.0030823117338003502,
#  'JustinLawGuy': 0.0030823117338003502,
#  'Dsquared75': 0.0030823117338003502,
#  'kerlgirl62': 0.00287215411558669,
#  'scarver195829': 0.0028021015761821363,
#  'beshannonphotos': 0.0026619964973730297,
# ...

# %%
reply_out_degree_cent = pd.DataFrame(list(reply_out_degree_desc.items())[:10], columns=["User", "Out Degree Centrality"])
reply_out_degree_cent
# Out:
#               User  Out Degree Centrality
# 0      HajjiADavis               0.013100
# 1   diasporaonline               0.011419
# 2          fabucat               0.010368
# 3           koamac               0.006025
# 4     NotoriousRBF               0.005254
# 5   VincentDiazJr1               0.005254
# 6         Lee4Pete               0.005184
# 7      tomsommers1               0.005184
# 8  freelancerjourn               0.004904
# 9         Aly_Dar8               0.004904

# %%
# Reply in-degree / Retweet in-degree (to find out if there are users/tweets that are deeply unpopular due to many replies of disagreement [for high ratios])
# Only use if retweet network can be constructed

# reply_in_degree_cent["In Degree Centrality"] / retweet_in_degree_cent["In Degree Centrality"]

# %% [markdown]
# ## Coronavirus

# %% [markdown]
# ### New York

# %%
quote_graph = nx.DiGraph()

for i in range(len(coronavirus_ny)):
    if type(coronavirus_ny.iloc[i]["quotedTweet"]) == str:
        quote_graph.add_edge(coronavirus_ny.iloc[i]["user"].split("/")[3], coronavirus_ny.iloc[i]["quotedTweet"].split("/")[3])
        
# nx.draw(quote_graph)
# nx.write_gexf(quote_graph, "gephi/us/coronavirus_newyork_quote_network.gexf")

# %%
quoted_betweenness = nx.betweenness_centrality(quote_graph)
quoted_betweenness_desc = dict(sorted(quoted_betweenness.items(), key=lambda item: item[1], reverse=True))
quoted_betweenness_desc
# Out:
# {'MarkLevineNYC': 7.369770108444061e-07,
#  'rafat': 4.737709355428325e-07,
#  'JuanMaBenitez': 4.211297204825178e-07,
#  'mattmfm': 2.105648602412589e-07,
#  'tomgara': 2.105648602412589e-07,
#  'DanMannarino': 2.105648602412589e-07,
#  'chefjoseandres': 2.105648602412589e-07,
#  'MarkTreyger718': 1.5792364518094417e-07,
#  'yuhline': 1.5792364518094417e-07,
#  'JustinBrannan': 1.5792364518094417e-07,
#  'UN_SDG': 1.0528243012062944e-07,
#  'es_indivisible': 1.0528243012062944e-07,
#  'middlechurch': 1.0528243012062944e-07,
#  'brian4NY': 1.0528243012062944e-07,
#  'CarlinaRivera': 1.0528243012062944e-07,
#  'celinegounder': 5.264121506031472e-08,
#  'jacobkornbluh': 5.264121506031472e-08,
#  'jonnybeec': 5.264121506031472e-08,
#  'ScottMuirMD': 5.264121506031472e-08,
#  'evanmcmurry': 5.264121506031472e-08,
#  'BenjaminGoggin': 5.264121506031472e-08,
#  'RyanKristafer': 5.264121506031472e-08,
#  'johnboost4': 5.264121506031472e-08,
#  'KarinOrantes': 5.264121506031472e-08,
# ...

# %%
quoted_betweenness_cent = pd.DataFrame(list(quoted_betweenness_desc.items())[:10], columns=["User", "Betweenness Centrality"])
quoted_betweenness_cent
# Out:
#              User  Betweenness Centrality
# 0   MarkLevineNYC            7.369770e-07
# 1           rafat            4.737709e-07
# 2   JuanMaBenitez            4.211297e-07
# 3         mattmfm            2.105649e-07
# 4         tomgara            2.105649e-07
# 5    DanMannarino            2.105649e-07
# 6  chefjoseandres            2.105649e-07
# 7  MarkTreyger718            1.579236e-07
# 8         yuhline            1.579236e-07
# 9   JustinBrannan            1.579236e-07

# %%
quoted_closeness = nx.closeness_centrality(quote_graph)
quoted_closeness_desc = dict(sorted(quoted_closeness.items(), key=lambda item: item[1], reverse=True))
quoted_closeness_desc
# Out:
# {'realDonaldTrump': 0.02081899518238128,
#  'NYGovCuomo': 0.013997676764366373,
#  'nytimes': 0.008029364533149804,
#  'thehill': 0.0077999541179169535,
#  'CNN': 0.006882312456985547,
#  'atrupar': 0.005047029135122735,
#  'NYCMayor': 0.004894088858300833,
#  'ABC': 0.004817618719889883,
#  'nypost': 0.004588208304657031,
#  'NBCNews': 0.003670566643725625,
#  'washingtonpost': 0.003670566643725625,
#  'CBSNews': 0.003211745813259922,
#  'JoeBiden': 0.003211745813259922,
#  'CNBC': 0.0029823353980270705,
#  'Acyn': 0.0027529249827942187,
#  'axios': 0.0027529249827942187,
#  'kylegriffin1': 0.0027529249827942187,
#  'business': 0.0027529249827942187,
#  'TheDailyShow': 0.002541161522579279,
#  'nowthisnews': 0.0025235145675613674,
#  'AP': 0.0025235145675613674,
#  'Reuters': 0.0025235145675613674,
#  'Quicktake': 0.0022941041523285156,
#  'NBCNewYork': 0.0022941041523285156,
#  'tomhanks': 0.0022941041523285156,
#  'Variety': 0.0020855492293895598,
# ...

# %%
quoted_closeness_cent = pd.DataFrame(list(quoted_closeness_desc.items())[:10], columns=["User", "Closeness Centrality"])
quoted_closeness_cent
# Out:
#               User  Closeness Centrality
# 0  realDonaldTrump              0.020819
# 1       NYGovCuomo              0.013998
# 2          nytimes              0.008029
# 3          thehill              0.007800
# 4              CNN              0.006882
# 5          atrupar              0.005047
# 6         NYCMayor              0.004894
# 7              ABC              0.004818
# 8           nypost              0.004588
# 9          NBCNews              0.003671

# %%
quoted_in_degree = nx.in_degree_centrality(quote_graph)
quoted_in_degree_desc = dict(sorted(quoted_in_degree.items(), key=lambda item: item[1], reverse=True))
quoted_in_degree_desc
# Out:
# {'realDonaldTrump': 0.02064693737095664,
#  'NYGovCuomo': 0.013994035329203946,
#  'nytimes': 0.008029364533149804,
#  'thehill': 0.0077999541179169535,
#  'CNN': 0.006882312456985546,
#  'atrupar': 0.005047029135122734,
#  'ABC': 0.004817618719889883,
#  'NYCMayor': 0.004817618719889883,
#  'nypost': 0.004588208304657031,
#  'NBCNews': 0.003670566643725625,
#  'washingtonpost': 0.003670566643725625,
#  'CBSNews': 0.003211745813259922,
#  'JoeBiden': 0.003211745813259922,
#  'CNBC': 0.0029823353980270705,
#  'Acyn': 0.0027529249827942187,
#  'axios': 0.0027529249827942187,
#  'kylegriffin1': 0.0027529249827942187,
#  'business': 0.0027529249827942187,
#  'nowthisnews': 0.002523514567561367,
#  'AP': 0.002523514567561367,
#  'Reuters': 0.002523514567561367,
#  'TheDailyShow': 0.002523514567561367,
#  'Quicktake': 0.0022941041523285156,
#  'NBCNewYork': 0.0022941041523285156,
#  'tomhanks': 0.0022941041523285156,
#  'SkyNews': 0.0020646937370956643,
# ...

# %%
quoted_in_degree_cent = pd.DataFrame(list(quoted_in_degree_desc.items())[:10], columns=["User", "In Degree Centrality"])
quoted_in_degree_cent
# Out:
#               User  In Degree Centrality
# 0  realDonaldTrump              0.020647
# 1       NYGovCuomo              0.013994
# 2          nytimes              0.008029
# 3          thehill              0.007800
# 4              CNN              0.006882
# 5          atrupar              0.005047
# 6              ABC              0.004818
# 7         NYCMayor              0.004818
# 8           nypost              0.004588
# 9          NBCNews              0.003671

# %%
quoted_out_degree = nx.out_degree_centrality(quote_graph)
quoted_out_degree_desc = dict(sorted(quoted_out_degree.items(), key=lambda item: item[1], reverse=True))
quoted_out_degree_desc
# Out:
# {'KevinClamato': 0.010552879100711171,
#  'ruthiecab': 0.010094058270245468,
#  'ARaj_Energy': 0.008488185363615508,
#  'humbertorosero': 0.007111722872218398,
#  'Ingridebap': 0.0066529020417526955,
#  'lastbohemians': 0.006423491626519844,
#  'mnutty': 0.005735260380821289,
#  'tummler10': 0.005735260380821289,
#  'LindseyBoylan': 0.005735260380821289,
#  'RonWaxman': 0.005276439550355586,
#  'Mezikenyc': 0.005047029135122734,
#  'watergatesummer': 0.004588208304657031,
#  'GSarafan': 0.004588208304657031,
#  'alextarquinio': 0.0043587978894241795,
#  'TimFullerton': 0.003670566643725625,
#  'PrancingPapio': 0.003211745813259922,
#  'underbobbybaby': 0.003211745813259922,
#  'TheMrJayBrown': 0.0029823353980270705,
#  'Helen_Highly': 0.0029823353980270705,
#  'AnneofBrooklyn': 0.0029823353980270705,
#  'Malandander212': 0.0029823353980270705,
#  'AmBeautifulShow': 0.0027529249827942187,
#  'drantbradley': 0.0027529249827942187,
#  'SidArthurNYC': 0.002523514567561367,
# ...

# %%
quoted_out_degree_cent = pd.DataFrame(list(quoted_out_degree_desc.items())[:10], columns=["User", "Out Degree Centrality"])
quoted_out_degree_cent
# Out:
#              User  Out Degree Centrality
# 0    KevinClamato               0.010553
# 1       ruthiecab               0.010094
# 2     ARaj_Energy               0.008488
# 3  humbertorosero               0.007112
# 4      Ingridebap               0.006653
# 5   lastbohemians               0.006423
# 6          mnutty               0.005735
# 7       tummler10               0.005735
# 8   LindseyBoylan               0.005735
# 9       RonWaxman               0.005276

# %%
# No edges to use to create retweet network graph

retweet_sources, retweet_target = [], []

for i in range(len(coronavirus_ny)):
    if type(coronavirus_ny.iloc[i]["retweetedTweet"]) == str:
        retweet_sources.append(coronavirus_ny.iloc[i]["user"].split("/")[3])
        retweet_target.append(coronavirus_ny.iloc[i]["retweetedTweet"].split("/")[3])
        
retweet_sources, retweet_target
# Out:
# ([], [])

# %%
reply_graph = nx.DiGraph()

for i in range(len(coronavirus_ny)):
    if type(coronavirus_ny.iloc[i]["inReplyToUser"]) == str:
        reply_graph.add_edge(coronavirus_ny.iloc[i]["user"].split("/")[3], coronavirus_ny.iloc[i]["inReplyToUser"].split("/")[3])
        
# nx.draw(reply_graph)
# nx.write_gexf(quote_graph, "gephi/us/coronavirus_newyork_reply_network.gexf")

# %%
reply_betweenness = nx.betweenness_centrality(reply_graph)
reply_betweenness_desc = dict(sorted(reply_betweenness.items(), key=lambda item: item[1], reverse=True))
reply_betweenness_desc
# Out:
# {'SquarePegDem': 3.654374647918877e-06,
#  'bobhardt': 2.1449590324741236e-06,
#  'RobGeorge': 1.3108082976230755e-06,
#  'MarkLevineNYC': 1.0327580526727262e-06,
#  'ClaudeBrodesser': 9.533151255440549e-07,
#  'AnnieTangent': 3.17771708514685e-07,
#  'alextarquinio': 1.588858542573425e-07,
#  'RMillennielle': 7.944292712867125e-08,
#  'JoeBorelliNYC': 3.972146356433562e-08,
#  'CarriageCavalry': 3.972146356433562e-08,
#  'AbbyChavaStein': 3.972146356433562e-08,
#  'MarkTreyger718': 3.972146356433562e-08,
#  'IM4NY': 0.0,
#  'PBSlade': 0.0,
#  'HAUPINC': 0.0,
#  'H_H_Elfrink': 0.0,
#  'CollinRugg': 0.0,
#  'CFBGod69': 0.0,
#  'EricAbbenante': 0.0,
#  'UdderlyFoxed': 0.0,
#  'DrEliDavid': 0.0,
#  'BwayCarl': 0.0,
#  'StevenTHatton2': 0.0,
#  'tdzarnick': 0.0,
#  'bennyjohnson': 0.0,
#  'CadhlaFirth': 0.0,
#  'PBMiller63': 0.0,
#  'MarshaBlackburn': 0.0,
#  'DoctorMrMD': 0.0,
#  'JasonMillerinDC': 0.0,
#  'XIXTRIX': 0.0,
#  '58_ballard': 0.0,
#  'SNap33': 0.0,
#  'DailyCaller': 0.0,
# ...

# %%
reply_betweenness_cent = pd.DataFrame(list(reply_betweenness_desc.items())[:10], columns=["User", "Betweenness Centrality"])
reply_betweenness_cent
# Out:
#               User  Betweenness Centrality
# 0     SquarePegDem            3.654375e-06
# 1         bobhardt            2.144959e-06
# 2        RobGeorge            1.310808e-06
# 3    MarkLevineNYC            1.032758e-06
# 4  ClaudeBrodesser            9.533151e-07
# 5     AnnieTangent            3.177717e-07
# 6    alextarquinio            1.588859e-07
# 7    RMillennielle            7.944293e-08
# 8    JoeBorelliNYC            3.972146e-08
# 9  CarriageCavalry            3.972146e-08

# %%
reply_closeness = nx.closeness_centrality(reply_graph)
reply_closeness_desc = dict(sorted(reply_closeness.items(), key=lambda item: item[1], reverse=True))
reply_closeness_desc
# Out:
# {'realDonaldTrump': 0.025508170585890794,
#  'NYGovCuomo': 0.008374397623102285,
#  'thehill': 0.00438421681944998,
#  'WhiteHouse45': 0.0035870864886408927,
#  'CNN': 0.0035870864886408927,
#  'JoeBiden': 0.0025906735751295338,
#  'nytimes': 0.0025906735751295338,
#  'chrislhayes': 0.0019928258270227183,
#  'nypost': 0.0019811033221578786,
#  'atrupar': 0.0017935432443204463,
#  'JoyAnnReid': 0.0017935432443204463,
#  'Yamiche': 0.0017935432443204463,
#  'charliekirk11': 0.0017935432443204463,
#  'gtconway3d': 0.0015942606616181746,
#  'washingtonpost': 0.0015942606616181746,
#  'SenSchumer': 0.0015942606616181746,
#  'CNNPolitics': 0.0015942606616181746,
#  'Mike_Pence': 0.0015942606616181746,
#  'MollyJongFast': 0.0015942606616181746,
#  'AOC': 0.0015942606616181746,
#  'kylegriffin1': 0.0013949780789159027,
#  'FLOTUS45': 0.0013949780789159027,
#  'Acosta': 0.0013949780789159027,
#  'ABC7NY': 0.0013949780789159027,
#  'GOP': 0.0013949780789159027,
# ...

# %%
reply_closeness_cent = pd.DataFrame(list(reply_closeness_desc.items())[:10], columns=["User", "Closeness Centrality"])
reply_closeness_cent
# Out:
#               User  Closeness Centrality
# 0  realDonaldTrump              0.025508
# 1       NYGovCuomo              0.008374
# 2          thehill              0.004384
# 3     WhiteHouse45              0.003587
# 4              CNN              0.003587
# 5         JoeBiden              0.002591
# 6          nytimes              0.002591
# 7      chrislhayes              0.001993
# 8           nypost              0.001981
# 9          atrupar              0.001794

# %%
reply_in_degree = nx.in_degree_centrality(reply_graph)
reply_in_degree_desc = dict(sorted(reply_in_degree.items(), key=lambda item: item[1], reverse=True))
reply_in_degree_desc
# Out:
# {'realDonaldTrump': 0.025508170585890794,
#  'NYGovCuomo': 0.008369868473495417,
#  'thehill': 0.00438421681944998,
#  'WhiteHouse45': 0.003587086488640893,
#  'CNN': 0.003587086488640893,
#  'JoeBiden': 0.0025906735751295338,
#  'nytimes': 0.0025906735751295338,
#  'nypost': 0.0019928258270227183,
#  'chrislhayes': 0.0019928258270227183,
#  'atrupar': 0.0017935432443204466,
#  'JoyAnnReid': 0.0017935432443204466,
#  'Yamiche': 0.0017935432443204466,
#  'charliekirk11': 0.0017935432443204466,
#  'gtconway3d': 0.0015942606616181746,
#  'washingtonpost': 0.0015942606616181746,
#  'SenSchumer': 0.0015942606616181746,
#  'CNNPolitics': 0.0015942606616181746,
#  'Mike_Pence': 0.0015942606616181746,
#  'MollyJongFast': 0.0015942606616181746,
#  'AOC': 0.0015942606616181746,
#  'kylegriffin1': 0.0013949780789159027,
#  'FLOTUS45': 0.0013949780789159027,
#  'Acosta': 0.0013949780789159027,
#  'ABC7NY': 0.0013949780789159027,
#  'GOP': 0.0013949780789159027,
# ...

# %%
reply_in_degree_cent = pd.DataFrame(list(reply_in_degree_desc.items())[:10], columns=["User", "In Degree Centrality"])
reply_in_degree_cent
# Out:
#               User  In Degree Centrality
# 0  realDonaldTrump              0.025508
# 1       NYGovCuomo              0.008370
# 2          thehill              0.004384
# 3     WhiteHouse45              0.003587
# 4              CNN              0.003587
# 5         JoeBiden              0.002591
# 6          nytimes              0.002591
# 7           nypost              0.001993
# 8      chrislhayes              0.001993
# 9          atrupar              0.001794

# %%
reply_out_degree = nx.out_degree_centrality(reply_graph)
reply_out_degree_desc = dict(sorted(reply_out_degree.items(), key=lambda item: item[1], reverse=True))
reply_out_degree_desc
# Out:
# {'Israelmarrero10': 0.01733758469509765,
#  'KevinClamato': 0.016739736946990835,
#  'RonWaxman': 0.014348345954563572,
#  'Helen_Highly': 0.01195695496213631,
#  'Lindasantangel1': 0.010163411717815863,
#  'lu_lu52': 0.00996412913511359,
#  'Lauryn2000': 0.00876843363889996,
#  'RMontea4': 0.0073734555599840575,
#  'IsraelRoseMarr1': 0.0073734555599840575,
#  'bjorn6': 0.007174172977281786,
#  'WilmaAr01465843': 0.007174172977281786,
#  'glrosario_': 0.005978477481068155,
#  'Newarkguy1973': 0.005579912315663611,
#  'humbertorosero': 0.005579912315663611,
#  'SquarePegDem': 0.004184934236747709,
#  'FanaticalModera': 0.004184934236747709,
#  'pluna00': 0.0039856516540454365,
#  'jstawicki': 0.003587086488640893,
#  'RussOnPolitics': 0.003387803905938621,
#  'ThugAngel11': 0.003387803905938621,
#  'actravlr': 0.003387803905938621,
#  'Ingridebap': 0.0031885213232363493,
#  'DavidOlabisiAFR': 0.0029892387405340776,
#  'OicOzzie': 0.0027899561578318055,
# ...

# %%
reply_out_degree_cent = pd.DataFrame(list(reply_out_degree_desc.items())[:10], columns=["User", "Out Degree Centrality"])
reply_out_degree_cent
# Out:
#               User  Out Degree Centrality
# 0  Israelmarrero10               0.017338
# 1     KevinClamato               0.016740
# 2        RonWaxman               0.014348
# 3     Helen_Highly               0.011957
# 4  Lindasantangel1               0.010163
# 5          lu_lu52               0.009964
# 6       Lauryn2000               0.008768
# 7         RMontea4               0.007373
# 8  IsraelRoseMarr1               0.007373
# 9           bjorn6               0.007174

# %%
# Reply in-degree / Retweet in-degree (to find out if there are users/tweets that are deeply unpopular due to many replies of disagreement [for high ratios])
# Only use if retweet network can be constructed

# reply_in_degree_cent["In Degree Centrality"] / retweet_in_degree_cent["In Degree Centrality"]

# %% [markdown]
# ### Washington

# %%
quote_graph = nx.DiGraph()

for i in range(len(coronavirus_washington)):
    if type(coronavirus_washington.iloc[i]["quotedTweet"]) == str:
        quote_graph.add_edge(coronavirus_washington.iloc[i]["user"].split("/")[3], coronavirus_washington.iloc[i]["quotedTweet"].split("/")[3])
        
# nx.draw(quote_graph)
# nx.write_gexf(quote_graph, "gephi/us/coronavirus_washington_quote_network.gexf")

# %%
quoted_betweenness = nx.betweenness_centrality(quote_graph)
quoted_betweenness_desc = dict(sorted(quoted_betweenness.items(), key=lambda item: item[1], reverse=True))
quoted_betweenness_desc
# Out:
# {'atrupar': 3.155246986423603e-05,
#  'W7VOA': 6.41566887239466e-06,
#  'gtconway3d': 2.7345473882337893e-06,
#  'DanielleMisiak': 2.629372488686336e-06,
#  'falcicchio': 1.682798392759255e-06,
#  'MurielBowser': 1.5776234932118016e-06,
#  'albamonica': 1.2620987945694412e-06,
#  'chefjoseandres': 1.2620987945694412e-06,
#  'CalebJHull': 1.0517489954745343e-06,
#  'caroljoynt': 5.258744977372672e-07,
#  'ChrisSheridan34': 5.258744977372672e-07,
#  'womeninGH': 5.258744977372672e-07,
#  'karentravers': 4.2069959818981376e-07,
#  'mehdirhasan': 3.155246986423603e-07,
#  'robbysoave': 2.1034979909490688e-07,
#  'josh_wingrove': 2.1034979909490688e-07,
#  'benstracy': 2.1034979909490688e-07,
#  'Richard_McBride': 2.1034979909490688e-07,
#  'RonaldKlain': 2.1034979909490688e-07,
#  'FutureDr_Drea': 1.0517489954745344e-07,
#  'alexnazaryan': 1.0517489954745344e-07,
#  'ZacharyforWard5': 1.0517489954745344e-07,
#  'John_Hudson': 1.0517489954745344e-07,
# ...

# %%
quoted_betweenness_cent = pd.DataFrame(list(quoted_betweenness_desc.items())[:10], columns=["User", "Betweenness Centrality"])
quoted_betweenness_cent
# Out:
#              User  Betweenness Centrality
# 0         atrupar            3.155247e-05
# 1           W7VOA            6.415669e-06
# 2      gtconway3d            2.734547e-06
# 3  DanielleMisiak            2.629372e-06
# 4      falcicchio            1.682798e-06
# 5    MurielBowser            1.577623e-06
# 6      albamonica            1.262099e-06
# 7  chefjoseandres            1.262099e-06
# 8      CalebJHull            1.051749e-06
# 9      caroljoynt            5.258745e-07

# %%
quoted_closeness = nx.closeness_centrality(quote_graph)
quoted_closeness_desc = dict(sorted(quoted_closeness.items(), key=lambda item: item[1], reverse=True))
quoted_closeness_desc
# Out:
# {'realDonaldTrump': 0.029231389850587743,
#  'MayorBowser': 0.008843296781039971,
#  'thehill': 0.007133592736705577,
#  'CNN': 0.00585278858625162,
#  'ABC': 0.005802080746198636,
#  'atrupar': 0.005206081567949272,
#  'Reuters': 0.005188067444876784,
#  'JoeBiden': 0.004559824902723736,
#  'NBCNews': 0.004539559014267186,
#  'AP': 0.004215304798962386,
#  'washingtonpost': 0.004215304798962386,
#  'GovLarryHogan': 0.004215304798962386,
#  'nytimes': 0.004215304798962386,
#  'ChrisMurphyCT': 0.0036665668961388806,
#  'NPR': 0.00324254215304799,
#  'MSNBC': 0.00324254215304799,
#  'tomhanks': 0.00324254215304799,
#  'THEHermanCain': 0.003163669506081957,
#  'Brandi_Buchman': 0.003163669506081957,
#  'carlquintanilla': 0.003163669506081957,
#  'SpeakerMcCarthy': 0.0029477655936799908,
#  'CNBC': 0.0029182879377431907,
#  'axios': 0.0029182879377431907,
#  'Yamiche': 0.0029182879377431907,
#  'kylegriffin1': 0.0029182879377431907,
#  'DanScavino': 0.0029182879377431907,
# ...

# %%
quoted_closeness_cent = pd.DataFrame(list(quoted_closeness_desc.items())[:10], columns=["User", "Closeness Centrality"])
quoted_closeness_cent
# Out:
#               User  Closeness Centrality
# 0  realDonaldTrump              0.029231
# 1      MayorBowser              0.008843
# 2          thehill              0.007134
# 3              CNN              0.005853
# 4              ABC              0.005802
# 5          atrupar              0.005206
# 6          Reuters              0.005188
# 7         JoeBiden              0.004560
# 8          NBCNews              0.004540
# 9               AP              0.004215

# %%
quoted_in_degree = nx.in_degree_centrality(quote_graph)
quoted_in_degree_desc = dict(sorted(quoted_in_degree.items(), key=lambda item: item[1], reverse=True))
quoted_in_degree_desc
# Out:
# {'realDonaldTrump': 0.028534370946822308,
#  'MayorBowser': 0.008754863813229572,
#  'thehill': 0.007133592736705577,
#  'CNN': 0.005836575875486381,
#  'atrupar': 0.005512321660181582,
#  'Reuters': 0.0048638132295719845,
#  'JoeBiden': 0.004539559014267185,
#  'NBCNews': 0.004539559014267185,
#  'AP': 0.004215304798962386,
#  'washingtonpost': 0.004215304798962386,
#  'GovLarryHogan': 0.004215304798962386,
#  'nytimes': 0.004215304798962386,
#  'ABC': 0.0038910505836575876,
#  'NPR': 0.0032425421530479894,
#  'MSNBC': 0.0032425421530479894,
#  'tomhanks': 0.0032425421530479894,
#  'SpeakerMcCarthy': 0.0029182879377431907,
#  'CNBC': 0.0029182879377431907,
#  'axios': 0.0029182879377431907,
#  'Yamiche': 0.0029182879377431907,
#  'kylegriffin1': 0.0029182879377431907,
#  'ScottGottliebMD': 0.0025940337224383916,
#  'fox5dc': 0.0025940337224383916,
#  'LeaderMcConnell': 0.0025940337224383916,
#  'WhiteHouse45': 0.0025940337224383916,
#  'CBSNews': 0.0025940337224383916,
# ...

# %%
quoted_in_degree_cent = pd.DataFrame(list(quoted_in_degree_desc.items())[:10], columns=["User", "In Degree Centrality"])
quoted_in_degree_cent
# Out:
#               User  In Degree Centrality
# 0  realDonaldTrump              0.028534
# 1      MayorBowser              0.008755
# 2          thehill              0.007134
# 3              CNN              0.005837
# 4          atrupar              0.005512
# 5          Reuters              0.004864
# 6         JoeBiden              0.004540
# 7          NBCNews              0.004540
# 8               AP              0.004215
# 9   washingtonpost              0.004215

# %%
quoted_out_degree = nx.out_degree_centrality(quote_graph)
quoted_out_degree_desc = dict(sorted(quoted_out_degree.items(), key=lambda item: item[1], reverse=True))
quoted_out_degree_desc
# Out:
# {'suzannelynch1': 0.013618677042801557,
#  'Dsquared75': 0.011673151750972763,
#  'cdorobek': 0.00940337224383917,
#  'therockyfiles': 0.00940337224383917,
#  'miketheidealist': 0.00907911802853437,
#  'sanambna': 0.008430609597924773,
#  'funkyartist': 0.008106355382619973,
#  'KelseyDuckett': 0.008106355382619973,
#  'New_Columbia': 0.006809338521400778,
#  'Aly_Dar8': 0.006485084306095979,
#  'atrupar': 0.00616083009079118,
#  'freelancerjourn': 0.00616083009079118,
#  'PositivelyBrie': 0.00616083009079118,
#  'DCNewsPhotog': 0.005836575875486381,
#  'biderman': 0.005512321660181582,
#  'DougSloan': 0.005512321660181582,
#  'RedWoofer': 0.005512321660181582,
#  'Cryn_Johannsen': 0.005512321660181582,
#  'phuffdaddy': 0.005188067444876783,
#  'KLF': 0.005188067444876783,
#  'TheJaniceTemple': 0.0048638132295719845,
#  'Dat2U': 0.0048638132295719845,
#  'Chris_nDC': 0.0048638132295719845,
#  'W7VOA': 0.004539559014267185,
#  'HajjiADavis': 0.004539559014267185,
# ...

# %%
quoted_out_degree_cent = pd.DataFrame(list(quoted_out_degree_desc.items())[:10], columns=["User", "Out Degree Centrality"])
quoted_out_degree_cent
# Out:
#               User  Out Degree Centrality
# 0    suzannelynch1               0.013619
# 1       Dsquared75               0.011673
# 2         cdorobek               0.009403
# 3    therockyfiles               0.009403
# 4  miketheidealist               0.009079
# 5         sanambna               0.008431
# 6      funkyartist               0.008106
# 7    KelseyDuckett               0.008106
# 8     New_Columbia               0.006809
# 9         Aly_Dar8               0.006485

# %%
# No edges to use to create retweet network graph

retweet_sources, retweet_target = [], []

for i in range(len(coronavirus_washington)):
    if type(coronavirus_washington.iloc[i]["retweetedTweet"]) == str:
        retweet_sources.append(coronavirus_washington.iloc[i]["user"].split("/")[3])
        retweet_target.append(coronavirus_washington.iloc[i]["retweetedTweet"].split("/")[3])
        
retweet_sources, retweet_target
# Out:
# ([], [])

# %%
reply_graph = nx.DiGraph()

for i in range(len(coronavirus_washington)):
    if type(coronavirus_washington.iloc[i]["inReplyToUser"]) == str:
        reply_graph.add_edge(coronavirus_washington.iloc[i]["user"].split("/")[3], coronavirus_washington.iloc[i]["inReplyToUser"].split("/")[3])
        
# nx.draw(reply_graph)
# nx.write_gexf(quote_graph, "gephi/us/coronavirus_washington_reply_network.gexf")

# %%
reply_betweenness = nx.betweenness_centrality(reply_graph)
reply_betweenness_desc = dict(sorted(reply_betweenness.items(), key=lambda item: item[1], reverse=True))
reply_betweenness_desc
# Out:
# {'atrupar': 1.0232513402034428e-06,
#  'nathanking': 6.821675601356286e-07,
#  'DMVBlackLives': 5.116256701017214e-07,
#  'MrTinDC': 3.410837800678143e-07,
#  'HollyLiveFox5DC': 1.7054189003390714e-07,
#  'BlakeMcCoyTV': 1.7054189003390714e-07,
#  'kikilitalien': 1.7054189003390714e-07,
#  'jimfusillibooks': 0.0,
#  'MarshaBlackburn': 0.0,
#  'cactusapinyona': 0.0,
#  'JoeKleinberg1': 0.0,
#  'ajstock6': 0.0,
#  'whstancil': 0.0,
#  'SenTedCruz': 0.0,
#  'WTopelius': 0.0,
#  'SpeakerMcCarthy': 0.0,
#  'JenMars72': 0.0,
#  'crashfrog': 0.0,
#  'zeynep': 0.0,
#  'ZcohenCNN': 0.0,
#  'CollinRugg': 0.0,
#  'BartonFairfax': 0.0,
#  'WSJ': 0.0,
#  'TheMencher': 0.0,
#  'b96165722': 0.0,
#  'cgowlvUSA': 0.0,
#  'GPIngersoll': 0.0,
#  'gekaminsky': 0.0,
#  'HajjiADavis': 0.0,
#  'AugeForTrump': 0.0,
#  'RealPotatus': 0.0,
#  'Saber_373': 0.0,
#  'RepMTG': 0.0,
#  '_Long_Field_': 0.0,
#  'LovelyLassSandy': 0.0,
#  'DrAseemMalhotra': 0.0,
#  'kevinfolta': 0.0,
#  'MiketheScribe': 0.0,
# ...

# %%
reply_betweenness_cent = pd.DataFrame(list(reply_betweenness_desc.items())[:10], columns=["User", "Betweenness Centrality"])
reply_betweenness_cent
# Out:
#               User  Betweenness Centrality
# 0          atrupar            1.023251e-06
# 1       nathanking            6.821676e-07
# 2    DMVBlackLives            5.116257e-07
# 3          MrTinDC            3.410838e-07
# 4  HollyLiveFox5DC            1.705419e-07
# 5     BlakeMcCoyTV            1.705419e-07
# 6     kikilitalien            1.705419e-07
# 7  jimfusillibooks            0.000000e+00
# 8  MarshaBlackburn            0.000000e+00
# 9   cactusapinyona            0.000000e+00

# %%
reply_closeness = nx.closeness_centrality(reply_graph)
reply_closeness_desc = dict(sorted(reply_closeness.items(), key=lambda item: item[1], reverse=True))
reply_closeness_desc
# Out:
# {'realDonaldTrump': 0.026424442609413706,
#  'WhiteHouse45': 0.0053674649050371595,
#  'kylegriffin1': 0.0037159372419488025,
#  'Mike_Pence': 0.0037159372419488025,
#  'GOP': 0.0033030553261767133,
#  'SpeakerMcCarthy': 0.002890173410404624,
#  'thehill': 0.002890173410404624,
#  'MSNBC': 0.002890173410404624,
#  'washingtonpost': 0.002890173410404624,
#  'CNN': 0.002477291494632535,
#  'politico': 0.002477291494632535,
#  'charliekirk11': 0.002064409578860446,
#  'DonaldJTrumpJr': 0.002064409578860446,
#  'marcorubio': 0.002064409578860446,
#  'Acyn': 0.002064409578860446,
#  'IvankaTrump': 0.002064409578860446,
#  'PressSec45': 0.002064409578860446,
#  'joshtpm': 0.002064409578860446,
#  'GOPChairwoman': 0.0016515276630883566,
#  'funder': 0.0016515276630883566,
#  'LindseyGrahamSC': 0.0016515276630883566,
#  'JoeBiden': 0.0016515276630883566,
#  'LeaderMcConnell': 0.0016515276630883566,
#  'RawStory': 0.0016515276630883566,
#  'soledadobrien': 0.0016515276630883566,
# ...

# %%
reply_closeness_cent = pd.DataFrame(list(reply_closeness_desc.items())[:10], columns=["User", "Closeness Centrality"])
reply_closeness_cent
# Out:
#               User  Closeness Centrality
# 0  realDonaldTrump              0.026424
# 1     WhiteHouse45              0.005367
# 2     kylegriffin1              0.003716
# 3       Mike_Pence              0.003716
# 4              GOP              0.003303
# 5  SpeakerMcCarthy              0.002890
# 6          thehill              0.002890
# 7            MSNBC              0.002890
# 8   washingtonpost              0.002890
# 9              CNN              0.002477

# %%
reply_in_degree = nx.in_degree_centrality(reply_graph)
reply_in_degree_desc = dict(sorted(reply_in_degree.items(), key=lambda item: item[1], reverse=True))
reply_in_degree_desc
# Out:
# {'realDonaldTrump': 0.026424442609413706,
#  'WhiteHouse45': 0.005367464905037159,
#  'kylegriffin1': 0.0037159372419488025,
#  'Mike_Pence': 0.0037159372419488025,
#  'GOP': 0.0033030553261767133,
#  'SpeakerMcCarthy': 0.002890173410404624,
#  'thehill': 0.002890173410404624,
#  'MSNBC': 0.002890173410404624,
#  'washingtonpost': 0.002890173410404624,
#  'CNN': 0.002477291494632535,
#  'politico': 0.002477291494632535,
#  'charliekirk11': 0.002064409578860446,
#  'DonaldJTrumpJr': 0.002064409578860446,
#  'marcorubio': 0.002064409578860446,
#  'Acyn': 0.002064409578860446,
#  'IvankaTrump': 0.002064409578860446,
#  'PressSec45': 0.002064409578860446,
#  'joshtpm': 0.002064409578860446,
#  'GOPChairwoman': 0.0016515276630883566,
#  'funder': 0.0016515276630883566,
#  'LindseyGrahamSC': 0.0016515276630883566,
#  'JoeBiden': 0.0016515276630883566,
#  'LeaderMcConnell': 0.0016515276630883566,
#  'RawStory': 0.0016515276630883566,
#  'soledadobrien': 0.0016515276630883566,
# ...

# %%
reply_in_degree_cent = pd.DataFrame(list(reply_in_degree_desc.items())[:10], columns=["User", "In Degree Centrality"])
reply_in_degree_cent
# Out:
#               User  In Degree Centrality
# 0  realDonaldTrump              0.026424
# 1     WhiteHouse45              0.005367
# 2     kylegriffin1              0.003716
# 3       Mike_Pence              0.003716
# 4              GOP              0.003303
# 5  SpeakerMcCarthy              0.002890
# 6          thehill              0.002890
# 7            MSNBC              0.002890
# 8   washingtonpost              0.002890
# 9              CNN              0.002477

# %%
reply_out_degree = nx.out_degree_centrality(reply_graph)
reply_out_degree_desc = dict(sorted(reply_out_degree.items(), key=lambda item: item[1], reverse=True))
reply_out_degree_desc
# Out:
# {'HajjiADavis': 0.02972749793559042,
#  'freelancerjourn': 0.016515276630883566,
#  'Hoosier84': 0.012799339388934764,
#  'fabucat': 0.010734929810074317,
#  'twright55': 0.010322047894302229,
#  'VincentDiazJr1': 0.00990916597853014,
#  'orecule': 0.009496284062758051,
#  'Steadyruncho123': 0.007844756399669695,
#  'francvs': 0.007431874483897605,
#  'Chris_nDC': 0.007018992568125515,
#  'JustinLawGuy': 0.006193228736581338,
#  'kerlgirl62': 0.006193228736581338,
#  'PhantomALERTCEO': 0.006193228736581338,
#  'cefilby': 0.005780346820809248,
#  'subBurgher': 0.00495458298926507,
#  'scarver195829': 0.00495458298926507,
#  'Aly_Dar8': 0.004541701073492981,
#  'DougSloan': 0.004541701073492981,
#  'sarah_margolis': 0.004541701073492981,
#  'BigGreenBlog': 0.004541701073492981,
#  'diasporaonline': 0.004128819157720892,
#  'marcmurd': 0.004128819157720892,
#  'sharynbovat': 0.004128819157720892,
#  'Dsquared75': 0.0037159372419488025,
#  'aardvarkwizard': 0.0037159372419488025,
# ...

# %%
reply_out_degree_cent = pd.DataFrame(list(reply_out_degree_desc.items())[:10], columns=["User", "Out Degree Centrality"])
reply_out_degree_cent
# Out:
#               User  Out Degree Centrality
# 0      HajjiADavis               0.029727
# 1  freelancerjourn               0.016515
# 2        Hoosier84               0.012799
# 3          fabucat               0.010735
# 4        twright55               0.010322
# 5   VincentDiazJr1               0.009909
# 6          orecule               0.009496
# 7  Steadyruncho123               0.007845
# 8          francvs               0.007432
# 9        Chris_nDC               0.007019

# %%
# Reply in-degree / Retweet in-degree (to find out if there are users/tweets that are deeply unpopular due to many replies of disagreement [for high ratios])
# Only use if retweet network can be constructed

# reply_in_degree_cent["In Degree Centrality"] / retweet_in_degree_cent["In Degree Centrality"]
