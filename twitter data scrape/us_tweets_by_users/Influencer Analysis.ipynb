# %%
import pandas as pd
import os
import pickle

import preprocessor as p
import re
import contractions
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()

import gensim
from gensim.utils import simple_preprocess
import gensim.corpora as corpora
from gensim.test.utils import datapath

# %%
quote_csv = [f"Quote Network/{file}" for file in os.listdir("Quote Network") if file.endswith(".csv")]
reply_csv = [f"Reply Network/{file}" for file in os.listdir("Reply Network") if file.endswith(".csv")]

# %%
lemmatizer = WordNetLemmatizer()

def lemmatize_words(text):
    return " ".join([lemmatizer.lemmatize(word) for word in text])

def clean_tweet(tweet, column):
    ## remove contractions
    tweet[column] = tweet[column].apply(lambda x: [contractions.fix(word) for word in x.split()])

    ## convert back into string so that tokenization can be done
    tweet[column] = [' '.join(map(str, l)) for l in tweet[column]]

    ## tokenize
    tweet[column] = tweet[column].apply(word_tokenize)

    ## convert tokens to lowercase
    tweet[column] = tweet[column].apply(lambda x: [word.lower() for word in x])

    ## remove punctuations and numerics
    tweet[column] = tweet[column].apply(lambda x: [word for word in x if re.search('^[a-z]+$',word)])

    ## remove stopwords
    stop_list = stopwords.words('english')
    tweet[column] = tweet[column].apply(lambda x: [word for word in x if word not in stop_list])
    
    tweet[column] = tweet[column].apply(lambda x: lemmatize_words(x))
    return tweet

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

# %%
def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]

# %%
def check_topic(date, text):
    if date < '2020-03-22':
        lda_model = gensim.models.ldamodel.LdaModel.load(datapath("us_start_lda_model_15"))
        dictionary = corpora.Dictionary.load(datapath("us_start_lda_model_15.id2word"))
        num_topics = 15
        prefix = "US_Start_Topic_"
    elif date >= '2020-03-22' and date < '2020-05-01':
        lda_model = gensim.models.ldamodel.LdaModel.load(datapath("us_circuit_lda_model_11"))
        dictionary = corpora.Dictionary.load(datapath("us_circuit_lda_model_11.id2word"))
        num_topics = 11
        prefix = "US_Circuit_Topic_"
    elif date >= date >= '2020-05-01' and date < '2021-01-01':
        lda_model = gensim.models.ldamodel.LdaModel.load(datapath("us_2020_lda_model_7"))
        dictionary = corpora.Dictionary.load(datapath("us_2020_lda_model_7.id2word"))
        num_topics = 7
        prefix = "US_2020_Topic_"
    elif date >= date >= '2021-01-01' and date < '2022-01-01':
        lda_model = gensim.models.ldamodel.LdaModel.load(datapath("us_2021_lda_model_11"))
        dictionary = corpora.Dictionary.load(datapath("us_2021_lda_model_11.id2word"))
        num_topics = 11
        prefix = "US_2021_Topic_"
    else:
        lda_model = gensim.models.ldamodel.LdaModel.load(datapath("us_2022_lda_model_19"))
        dictionary = corpora.Dictionary.load(datapath("us_2022_lda_model_19.id2word"))
        num_topics = 19
        prefix = "US_2022_Topic_"
        
    corpus = dictionary.doc2bow(text)
    top_topics = lda_model.get_document_topics(corpus, minimum_probability=0.0)
    topic_vec = [top_topics[i][1] for i in range(num_topics)]
    return f"{prefix}{topic_vec.index(max(topic_vec))+1}"

# %%
def determine_sentiment(score):
    if score < 0:
        return "Negative"
    elif score > 0:
        return "Positive"
    else:
        return "Neutral"

# %%
def preprocess(text):
    text = p.clean(text)
    tokenization = word_tokenize(text) 
    stop_words = set(stopwords.words('english'))
    tokenization = [w for w in tokenization if not w in stop_words]   
    return text

# %%
def fake_or_real(pred):
    if pred == 0:
        return "Real"
    else:
        return "Fake"

# %%
def load_vectorizer_and_model():
    return pickle.load(open("../../models/misinformation/vectorizer.txt", "rb")), pickle.load(open("../../models/misinformation/logreg.txt", "rb"))

# %%
vectorizer, model = load_vectorizer_and_model()

# %%
modded_quote_dfs = []

for csv in quote_csv:
    df = pd.read_csv(csv)
    df2 = df.copy()
    df2 = clean_tweet(df, 'renderedContent')
    
    # Retrieve topics
    data = df2['renderedContent'].values.tolist()
    data_words = list(sent_to_words(data))
    # Build the bigram and trigram models
    bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
    trigram = gensim.models.Phrases(bigram[data_words], threshold=100)  
    # Faster way to get a sentence clubbed as a trigram/bigram
    bigram_mod = gensim.models.phrases.Phraser(bigram)
    trigram_mod = gensim.models.phrases.Phraser(trigram)
    data_words_trigrams = make_trigrams(data_words)
    topics = []
    for i in range(len(df2)):
        topics.append(check_topic(df2.iloc[i].date, data_words_trigrams[i]))
    df["Topic"] = topics
    
    # Calculate sentiments
    df2["renderedContent"] = df2['renderedContent'].apply(lambda tweet:str(tweet))
    sentiment_scores = df2['renderedContent'].apply(sid.polarity_scores)
    sentiments = sentiment_scores.apply(lambda x: x["compound"])
    sentiment_label = sentiments.apply(determine_sentiment)
    df["Sentiment"] = sentiment_label
    
    # Check if real / fake news
    df["renderedContent"] = df["renderedContent"].apply(preprocess)
    verdict_labels = []
    for i in range(len(df)):
        vectorized_text = vectorizer.transform([df.iloc[i].renderedContent])
        verdict_labels.append(fake_or_real(model.predict(vectorized_text)[0]))
    df["Verdict"] = verdict_labels
    
    modded_quote_dfs.append(df)

# %%
modded_quote_dfs
# Out:
# [                        date  \
#  0  2020-07-04 13:18:56+00:00
#  1  2020-07-03 03:53:57+00:00
#  2  2020-06-23 13:16:42+00:00
#  3  2020-05-28 02:16:43+00:00
#  4  2020-05-09 23:28:41+00:00
#  5  2020-04-30 23:24:09+00:00
#  6  2020-04-26 18:53:19+00:00
#  7  2020-04-07 13:25:41+00:00
#  8  2020-04-07 00:45:52+00:00
#
#                                       renderedContent  \
#  0  kim guilfoyle speaking indoor event south dako...
#  1                                 died covid florida
#  2  u rank world coronavirus test per million peop...
#  3  president acknowledged country surpassed covid...
#  4  kurtschlichter trump said merkel abe praised p...
#  5  astounding many people like brian kilmeade amp...
#  6  trump enjoyed vacation last month turned coron...
#  7  feb trump sent memo warning million american c...
#  8  one month ago today trump told u want let peop...
#
#                            user               Topic Sentiment Verdict
#  0  https://twitter.com/atrupar     US_2020_Topic_3  Positive    Fake
#  1  https://twitter.com/atrupar     US_2020_Topic_7  Negative    Fake
#  2  https://twitter.com/atrupar     US_2020_Topic_7  Negative    Fake
#  3  https://twitter.com/atrupar     US_2020_Topic_7  Negative    Fake
#  4  https://twitter.com/atrupar     US_2020_Topic_1  Positive    Fake
#  5  https://twitter.com/atrupar  US_Circuit_Topic_1  Positive    Real
#  6  https://twitter.com/atrupar  US_Circuit_Topic_1  Positive    Fake
#  7  https://twitter.com/atrupar  US_Circuit_Topic_7  Negative    Fake
#  8  https://twitter.com/atrupar  US_Circuit_Topic_7  Negative    Fake  ,
#  Empty DataFrame
#  Columns: [date, renderedContent, user, Topic, Sentiment, Verdict]
#  Index: [],
#                            date  \
#  0    2023-02-23 19:22:38+00:00
#  1    2023-01-27 09:33:58+00:00
#  2    2022-12-28 20:09:09+00:00
#  3    2022-12-14 23:04:46+00:00
#  4    2022-11-27 22:09:58+00:00
#  ..                         ...
#  340  2020-03-19 02:43:23+00:00
#  341  2020-03-17 06:36:02+00:00
#  342  2020-03-16 06:48:06+00:00
#  343  2020-03-13 19:18:32+00:00
#  344  2020-03-13 10:24:48+00:00
#
#                                         renderedContent  \
#  0    covidisnotover disappointing see closure know ...
#  1    healthequity sabrinatessep outstanding impactf...
#  2    apartheidspaceboy spread disinformation flitte...
#  3    demographic shift fueled covid delivered midte...
#  4    covid flu rsv mean mask need come back via nbc...
#  ..                                                 ...
#  340  alert u senate need include disability stimulu...
#  341  nih clinical trial investigational vaccine beg...
#  342  realdonaldtrump stop somuchwhining crooked fly...
#  343                                               true
#  344  testing good news amazingly helpful clevelandc...
#
#                                 user              Topic Sentiment Verdict
#  0    https://twitter.com/Dsquared75   US_2022_Topic_19  Negative    Fake
#  1    https://twitter.com/Dsquared75   US_2022_Topic_19  Positive    Fake
#  2    https://twitter.com/Dsquared75   US_2022_Topic_19   Neutral    Fake
#  3    https://twitter.com/Dsquared75    US_2022_Topic_2  Positive    Fake
#  4    https://twitter.com/Dsquared75   US_2022_Topic_14  Negative    Fake
#  ..                              ...                ...       ...     ...
#  340  https://twitter.com/Dsquared75   US_Start_Topic_3  Positive    Fake
#  341  https://twitter.com/Dsquared75  US_Start_Topic_13   Neutral    Fake
#  342  https://twitter.com/Dsquared75  US_Start_Topic_15  Negative    Fake
#  343  https://twitter.com/Dsquared75  US_Start_Topic_14  Positive    Fake
#  344  https://twitter.com/Dsquared75  US_Start_Topic_12  Positive    Fake
#
#  [345 rows x 6 columns],
#                           date  \
#  0   2022-10-28 19:12:43+00:00
#  1   2022-04-12 13:14:24+00:00
#  2   2022-03-05 15:01:27+00:00
#  3   2022-03-02 19:31:01+00:00
#  4   2022-02-12 21:35:09+00:00
#  5   2022-02-04 12:52:58+00:00
#  6   2022-01-10 00:01:07+00:00
#  7   2020-06-27 12:49:28+00:00
#  8   2020-06-23 20:17:37+00:00
#  9   2020-05-28 00:48:37+00:00
#  10  2020-05-22 02:07:38+00:00
#  11  2020-05-21 01:27:38+00:00
#  12  2020-05-08 10:57:40+00:00
#  13  2020-05-08 10:52:24+00:00
#  14  2020-05-05 10:40:49+00:00
#  15  2020-05-04 14:08:49+00:00
#  16  2020-04-29 15:13:06+00:00
#  17  2020-04-23 08:04:42+00:00
#  18  2020-04-14 00:31:53+00:00
#  19  2020-04-08 03:03:45+00:00
#  20  2020-04-08 03:03:41+00:00
#  21  2020-03-13 02:30:40+00:00
#  22  2020-03-11 14:51:22+00:00
#
#                                        renderedContent  \
#  0   posted meme conspiracy theory covid election a...
#  1   biden get blame today truth problem forget ast...
#  2   percent behavior regard seem make sense point ...
#  3   gosh really bad way getting protection covid w...
#  4   think read somewhere apparently big country so...
#  5   alyssafarah adamrippon also description covid ...
#  6   imagine march tucker carlson flew trump privat...
#  7   historian problem figuring principal reason am...
#  8   day since realdonaldtrump said case would go z...
#  9   trumpdeathclock pretty good provides running e...
#  10                         jaketapper right mask mask
#  11  fifteen time january february trump lauded xi ...
#  12  mishandling realdonaldtrump trump lying lack e...
#  13  american died rate one every second past month...
#  14  guess know keep president united state night a...
#  15   realdonaldtrump making claim told fine let u see
#  16  next time pollster ask biden supporter excited...
#  17  major catastrophe lay bare truth leader trump ...
#  18  remember realdonaldtrump said gop donor shortl...
#  19  office testing dead body instead referring sus...
#  20  monday afternoon new york city resident died c...
#  21  fox news viewer hearing tonight fault joe hunt...
#  22      realdonaldtrump said yesterday simply go away
#
#                                user               Topic Sentiment Verdict
#  0   https://twitter.com/gtconway3d    US_2022_Topic_13  Negative    Fake
#  1   https://twitter.com/gtconway3d     US_2022_Topic_4  Positive    Fake
#  2   https://twitter.com/gtconway3d    US_2022_Topic_17  Positive    Fake
#  3   https://twitter.com/gtconway3d     US_2022_Topic_3  Negative    Fake
#  4   https://twitter.com/gtconway3d     US_2022_Topic_3   Neutral    Fake
#  5   https://twitter.com/gtconway3d     US_2022_Topic_3   Neutral    Real
#  6   https://twitter.com/gtconway3d    US_2022_Topic_10  Negative    Fake
#  7   https://twitter.com/gtconway3d     US_2020_Topic_7  Negative    Fake
#  8   https://twitter.com/gtconway3d     US_2020_Topic_7  Positive    Fake
#  9   https://twitter.com/gtconway3d     US_2020_Topic_7  Positive    Fake
#  10  https://twitter.com/gtconway3d     US_2020_Topic_3   Neutral    Fake
#  11  https://twitter.com/gtconway3d     US_2020_Topic_1  Positive    Fake
#  12  https://twitter.com/gtconway3d     US_2020_Topic_4  Negative    Fake
#  13  https://twitter.com/gtconway3d     US_2020_Topic_1  Negative    Fake
#  14  https://twitter.com/gtconway3d     US_2020_Topic_1  Positive    Fake
#  15  https://twitter.com/gtconway3d     US_2020_Topic_6  Positive    Fake
#  16  https://twitter.com/gtconway3d  US_Circuit_Topic_8  Negative    Fake
#  17  https://twitter.com/gtconway3d  US_Circuit_Topic_5  Negative    Fake
#  18  https://twitter.com/gtconway3d  US_Circuit_Topic_7   Neutral    Fake
#  19  https://twitter.com/gtconway3d  US_Circuit_Topic_7  Negative    Fake
#  20  https://twitter.com/gtconway3d  US_Circuit_Topic_7  Negative    Real
#  21  https://twitter.com/gtconway3d    US_Start_Topic_4  Negative    Fake
#  22  https://twitter.com/gtconway3d    US_Start_Topic_3   Neutral    Fake  ,
#                             date  \
#  0     2022-07-14 10:49:51+00:00
#  1     2022-07-14 10:44:19+00:00
#  2     2022-07-14 10:37:14+00:00
#  3     2022-05-17 14:55:02+00:00
#  4     2022-04-11 05:25:49+00:00
#  ...                         ...
#  3554  2020-11-20 18:40:19+00:00
#  3555  2020-11-20 17:43:38+00:00
#  3556  2020-11-20 17:36:36+00:00
#  3557  2020-11-20 17:33:46+00:00
#  3558  2020-11-20 17:29:58+00:00
#
#                                          renderedContent  \
#  0     breaking news virginia new death hour virginia...
#  1     usa new death hour usa experience new covid de...
#  2     breaking news usa new death hour according nyt...
#  3     heerak christian kim republican candidate u co...
#  4     million chinese lockdown shanghai due allowed ...
#  ...                                                 ...
#  3554  breaking news virginia new case hour arlington...
#  3555  doubt maryland headed hell earth live maryland...
#  3556  maryland state see case increase fifth day pas...
#  3557  breaking news maryland new case hour see quick...
#  3558  unfortunately lot teen die flu season since ai...
#
#                                       user            Topic Sentiment Verdict
#  0     https://twitter.com/Heerak4Congress  US_2022_Topic_8  Negative    Fake
#  1     https://twitter.com/Heerak4Congress  US_2022_Topic_2  Negative    Fake
#  2     https://twitter.com/Heerak4Congress  US_2022_Topic_2  Negative    Fake
#  3     https://twitter.com/Heerak4Congress  US_2022_Topic_5   Neutral    Fake
#  4     https://twitter.com/Heerak4Congress  US_2022_Topic_2  Negative    Fake
#  ...                                   ...              ...       ...     ...
#  3554  https://twitter.com/Heerak4Congress  US_2020_Topic_7  Negative    Fake
#  3555  https://twitter.com/Heerak4Congress  US_2020_Topic_7  Negative    Fake
#  3556  https://twitter.com/Heerak4Congress  US_2020_Topic_7  Negative    Real
#  3557  https://twitter.com/Heerak4Congress  US_2020_Topic_7  Negative    Fake
#  3558  https://twitter.com/Heerak4Congress  US_2020_Topic_6  Negative    Fake
#
#  [3559 rows x 6 columns],
#                           date  \
#  0   2021-07-23 15:24:15+00:00
#  1   2021-06-19 12:06:45+00:00
#  2   2021-06-16 13:09:41+00:00
#  3   2021-05-22 16:33:51+00:00
#  4   2021-05-18 16:38:07+00:00
#  5   2021-05-13 13:27:23+00:00
#  6   2021-05-03 12:19:29+00:00
#  7   2021-04-21 13:18:21+00:00
#  8   2020-10-20 12:24:38+00:00
#  9   2020-08-03 19:30:39+00:00
#  10  2020-07-20 12:08:40+00:00
#  11  2020-07-18 12:44:01+00:00
#  12  2020-07-14 12:30:55+00:00
#  13  2020-06-25 13:28:25+00:00
#  14  2020-06-23 12:13:05+00:00
#  15  2020-03-11 23:13:36+00:00
#  16  2020-03-11 17:22:07+00:00
#
#                                        renderedContent  \
#  0   focus equity new district columbia pandemic he...
#  1   still time join u juneteenth community corp da...
#  2   looking opportunity give back help u get dc re...
#  3   big thank coordinating team behind two communi...
#  4   get free beer saturday get vaccine dcmonc pm d...
#  5   looking opportunity volunteer help u get dc re...
#  6   free vaccine dc hospitality worker today may h...
#  7   tell friend free vaccine ward resident today t...
#  8   dc need opt dc new amp secure exposure notific...
#  9   due incoming tropical storm following closed t...
#  10  due dangerously hot temperature monday july di...
#  11       free coronavirus testing available near http
#  12           today free coronavirus testing site http
#  13  today free testing site include site southwest...
#  14  thinking getting tested free site available ac...
#  15  wednesday march district coronavirus data incl...
#  16  join today pm provide update district response...
#
#                                 user              Topic Sentiment Verdict
#  0   https://twitter.com/MayorBowser    US_2021_Topic_7  Positive    Real
#  1   https://twitter.com/MayorBowser    US_2021_Topic_5  Positive    Real
#  2   https://twitter.com/MayorBowser    US_2021_Topic_5  Positive    Fake
#  3   https://twitter.com/MayorBowser   US_2021_Topic_10  Positive    Fake
#  4   https://twitter.com/MayorBowser    US_2021_Topic_5  Positive    Fake
#  5   https://twitter.com/MayorBowser    US_2021_Topic_5  Positive    Real
#  6   https://twitter.com/MayorBowser    US_2021_Topic_5  Positive    Real
#  7   https://twitter.com/MayorBowser   US_2021_Topic_10  Positive    Fake
#  8   https://twitter.com/MayorBowser    US_2020_Topic_7  Positive    Fake
#  9   https://twitter.com/MayorBowser    US_2020_Topic_5  Negative    Fake
#  10  https://twitter.com/MayorBowser    US_2020_Topic_7  Positive    Real
#  11  https://twitter.com/MayorBowser    US_2020_Topic_5  Positive    Fake
#  12  https://twitter.com/MayorBowser    US_2020_Topic_5  Positive    Fake
#  13  https://twitter.com/MayorBowser    US_2020_Topic_5  Positive    Real
#  14  https://twitter.com/MayorBowser    US_2020_Topic_5  Positive    Fake
#  15  https://twitter.com/MayorBowser  US_Start_Topic_14  Positive    Real
#  16  https://twitter.com/MayorBowser   US_Start_Topic_8  Positive    Real  ,
#  Empty DataFrame
#  Columns: [date, renderedContent, user, Topic, Sentiment, Verdict]
#  Index: [],
#                           date  \
#  0   2023-02-28 23:56:06+00:00
#  1   2023-02-28 23:11:05+00:00
#  2   2023-02-28 19:56:02+00:00
#  3   2023-02-28 19:36:02+00:00
#  4   2023-02-28 17:52:47+00:00
#  5   2023-02-28 17:46:06+00:00
#  6   2023-02-28 15:16:08+00:00
#  7   2023-02-28 14:51:04+00:00
#  8   2023-02-28 12:51:02+00:00
#  9   2023-02-28 10:06:07+00:00
#  10  2023-02-28 09:46:04+00:00
#  11  2023-02-28 07:06:05+00:00
#  12  2023-02-28 06:46:04+00:00
#  13  2023-02-28 01:36:06+00:00
#  14  2023-02-27 23:46:04+00:00
#  15  2023-02-27 21:51:07+00:00
#  16  2023-02-27 21:06:08+00:00
#  17  2023-02-27 15:29:15+00:00
#  18  2023-02-27 14:56:04+00:00
#  19  2023-02-27 14:46:07+00:00
#
#                                        renderedContent  \
#  0   john barrasso want congress debriefed energy d...
#  1              final answer origin remains reach http
#  2   china say open transparent covid origin tracin...
#  3    u ambassador china need honest origin covid http
#  4   birx u enough prevent another pandemic like co...
#  5               five takeaway big lab leak story http
#  6   new poll think covid came chinese lab occurred...
#  7               five takeaway big lab leak story http
#  8           new five takeaway big lab leak story http
#  9   rand paul call declassifying document showing ...
#  10  covid origin report reignites firestorm lab le...
#  11  rand paul call declassifying document showing ...
#  12  covid origin report reignites firestorm lab le...
#  13  white house covid lab leak theory definitive c...
#  14  new covid origin report reignites firestorm la...
#  15  state department biden senior official repeate...
#  16  white house covid lab leak theory definitive c...
#  17  rand paul call declassifying document showing ...
#  18  energy department concludes lab leak likely sp...
#  19  democrat entirely surprised energy covid lab l...
#
#                             user             Topic Sentiment Verdict
#  0   https://twitter.com/thehill  US_2022_Topic_16  Positive    Fake
#  1   https://twitter.com/thehill  US_2022_Topic_12  Positive    Fake
#  2   https://twitter.com/thehill  US_2022_Topic_12   Neutral    Fake
#  3   https://twitter.com/thehill   US_2022_Topic_9  Positive    Fake
#  4   https://twitter.com/thehill  US_2022_Topic_10  Positive    Fake
#  5   https://twitter.com/thehill  US_2022_Topic_11  Negative    Fake
#  6   https://twitter.com/thehill  US_2022_Topic_16   Neutral    Fake
#  7   https://twitter.com/thehill  US_2022_Topic_11  Negative    Fake
#  8   https://twitter.com/thehill  US_2022_Topic_11  Negative    Fake
#  9   https://twitter.com/thehill   US_2022_Topic_9   Neutral    Fake
#  10  https://twitter.com/thehill   US_2022_Topic_9  Negative    Fake
#  11  https://twitter.com/thehill   US_2022_Topic_9   Neutral    Fake
#  12  https://twitter.com/thehill   US_2022_Topic_9  Negative    Fake
#  13  https://twitter.com/thehill  US_2022_Topic_12  Negative    Fake
#  14  https://twitter.com/thehill   US_2022_Topic_9  Negative    Fake
#  15  https://twitter.com/thehill   US_2022_Topic_2   Neutral    Fake
#  16  https://twitter.com/thehill  US_2022_Topic_12  Negative    Fake
#  17  https://twitter.com/thehill   US_2022_Topic_9   Neutral    Fake
#  18  https://twitter.com/thehill   US_2022_Topic_7  Negative    Fake
#  19  https://twitter.com/thehill   US_2022_Topic_2  Positive    Fake  ,
#                          date  \
#  0  2023-02-28 17:03:07+00:00
#  1  2023-02-28 12:17:03+00:00
#  2  2023-02-28 01:34:54+00:00
#  3  2023-02-27 17:05:55+00:00
#  4  2023-02-27 15:44:04+00:00
#
#                                       renderedContent  \
#  0  much new compelling scientific front origin ex...
#  1  tuesday briefing supreme court weigh president...
#  2  lab leak theory started lab accident central c...
#  3  covid causing sharp rise case postural orthost...
#  4  analysis energy department report attributing ...
#
#                                   user             Topic Sentiment Verdict
#  0  https://twitter.com/washingtonpost  US_2022_Topic_13  Positive    Fake
#  1  https://twitter.com/washingtonpost   US_2022_Topic_6  Positive    Fake
#  2  https://twitter.com/washingtonpost  US_2022_Topic_16  Positive    Fake
#  3  https://twitter.com/washingtonpost   US_2022_Topic_9  Negative    Fake
#  4  https://twitter.com/washingtonpost   US_2022_Topic_1  Negative    Fake  ]

# %%
modded_reply_dfs = []

for csv in reply_csv:
    df = pd.read_csv(csv)
    df2 = df.copy()
    df2 = clean_tweet(df, 'renderedContent')
    
    # Retrieve topics
    data = df2['renderedContent'].values.tolist()
    data_words = list(sent_to_words(data))
    # Build the bigram and trigram models
    bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
    trigram = gensim.models.Phrases(bigram[data_words], threshold=100)  
    # Faster way to get a sentence clubbed as a trigram/bigram
    bigram_mod = gensim.models.phrases.Phraser(bigram)
    trigram_mod = gensim.models.phrases.Phraser(trigram)
    data_words_trigrams = make_trigrams(data_words)
    topics = []
    for i in range(len(df2)):
        topics.append(check_topic(df2.iloc[i].date, data_words_trigrams[i]))
    df["Topic"] = topics
    
    # Calculate sentiments
    df2["renderedContent"] = df2['renderedContent'].apply(lambda tweet:str(tweet))
    sentiment_scores = df2['renderedContent'].apply(sid.polarity_scores)
    sentiments = sentiment_scores.apply(lambda x: x["compound"])
    sentiment_label = sentiments.apply(determine_sentiment)
    df["Sentiment"] = sentiment_label
    
    # Check if real / fake news
    df["renderedContent"] = df["renderedContent"].apply(preprocess)
    verdict_labels = []
    for i in range(len(df)):
        vectorized_text = vectorizer.transform([df.iloc[i].renderedContent])
        verdict_labels.append(fake_or_real(model.predict(vectorized_text)[0]))
    df["Verdict"] = verdict_labels
    
    modded_reply_dfs.append(df)

# %%
modded_reply_dfs
# Out:
# [Empty DataFrame
#  Columns: [date, renderedContent, user, Topic, Sentiment, Verdict]
#  Index: [],
#                            date  \
#  0    2022-11-17 19:19:07+00:00
#  1    2022-11-10 23:33:12+00:00
#  2    2022-11-05 12:57:38+00:00
#  3    2022-11-05 00:06:29+00:00
#  4    2022-10-24 22:15:02+00:00
#  ..                         ...
#  223  2020-06-24 21:28:27+00:00
#  224  2020-06-21 16:59:30+00:00
#  225  2020-06-17 15:09:15+00:00
#  226  2020-06-14 15:11:33+00:00
#  227  2020-04-22 04:09:48+00:00
#
#                                         renderedContent  \
#  0                       ghostofsurf dineshdsouza covid
#  1                 two original three booster covid yet
#  2    mcgeheenaomi marypeltola rural king mom house ...
#  3          mcgeheenaomi marypeltola cool covid vaccine
#  4    pediatricnursey yeah policy get away failing c...
#  ..                                                 ...
#  223  imagine pissed trying keep people safe fuck ka...
#  224  covid antibody test negative sure feel coronav...
#  225      going get covid antibody test today wish luck
#  226  dc department health allowing bunch u health c...
#  227  jvaghyjones could new fun bowl like instead ga...
#
#                               user               Topic Sentiment Verdict
#  0    https://twitter.com/Aly_Dar8     US_2022_Topic_1   Neutral    Fake
#  1    https://twitter.com/Aly_Dar8    US_2022_Topic_14  Positive    Fake
#  2    https://twitter.com/Aly_Dar8     US_2022_Topic_1   Neutral    Fake
#  3    https://twitter.com/Aly_Dar8     US_2022_Topic_7  Positive    Fake
#  4    https://twitter.com/Aly_Dar8    US_2022_Topic_17  Positive    Fake
#  ..                            ...                 ...       ...     ...
#  223  https://twitter.com/Aly_Dar8     US_2020_Topic_6  Negative    Fake
#  224  https://twitter.com/Aly_Dar8     US_2020_Topic_5  Negative    Fake
#  225  https://twitter.com/Aly_Dar8     US_2020_Topic_5  Positive    Fake
#  226  https://twitter.com/Aly_Dar8     US_2020_Topic_5  Positive    Fake
#  227  https://twitter.com/Aly_Dar8  US_Circuit_Topic_1  Positive    Fake
#
#  [228 rows x 6 columns],
#                            date  \
#  0    2022-06-21 16:26:07+00:00
#  1    2021-10-14 06:16:21+00:00
#  2    2021-09-24 05:02:57+00:00
#  3    2021-08-20 16:21:23+00:00
#  4    2021-07-16 03:32:27+00:00
#  ..                         ...
#  290  2020-04-07 03:03:00+00:00
#  291  2020-04-07 03:02:59+00:00
#  292  2020-04-04 04:41:57+00:00
#  293  2020-04-02 20:46:18+00:00
#  294  2020-03-17 21:44:50+00:00
#
#                                         renderedContent  \
#  0    financeincommon riouxremy adamamko eib old tin...
#  1    pandemic center stage economic recovery narrat...
#  2    great lunch networking session format washingt...
#  3    africanbizmag worse local government aligned y...
#  4    democracynow many death accounted bleach solut...
#  ..                                                 ...
#  290  state minority luxury qhp allowed proactively ...
#  291  fatality picture trend divide inherent pandemi...
#  292  allafrica curbing fending responding exactly a...
#  293               migrant health worker frontline need
#  294  malaria killing africa yet resource contain ne...
#
#                                     user                Topic Sentiment Verdict
#  0    https://twitter.com/diasporaonline      US_2022_Topic_3  Negative    Fake
#  1    https://twitter.com/diasporaonline      US_2021_Topic_4  Positive    Fake
#  2    https://twitter.com/diasporaonline      US_2021_Topic_9  Positive    Real
#  3    https://twitter.com/diasporaonline      US_2021_Topic_7  Negative    Real
#  4    https://twitter.com/diasporaonline     US_2021_Topic_10  Negative    Fake
#  ..                                  ...                  ...       ...     ...
#  290  https://twitter.com/diasporaonline  US_Circuit_Topic_10  Positive    Fake
#  291  https://twitter.com/diasporaonline   US_Circuit_Topic_8  Negative    Fake
#  292  https://twitter.com/diasporaonline   US_Circuit_Topic_7  Positive    Fake
#  293  https://twitter.com/diasporaonline   US_Circuit_Topic_1   Neutral    Fake
#  294  https://twitter.com/diasporaonline     US_Start_Topic_3  Negative    Fake
#
#  [295 rows x 6 columns],
#                            date  \
#  0    2023-02-27 15:33:18+00:00
#  1    2023-01-15 15:37:24+00:00
#  2    2023-01-08 04:13:05+00:00
#  3    2022-12-28 06:16:44+00:00
#  4    2022-12-23 06:27:15+00:00
#  ..                         ...
#  143  2020-04-16 06:56:57+00:00
#  144  2020-04-10 21:35:42+00:00
#  145  2020-04-07 17:43:16+00:00
#  146  2020-03-31 15:33:31+00:00
#  147  2020-03-19 14:51:10+00:00
#
#                                         renderedContent  \
#  0    likely came wuhan china lab leak say news repo...
#  1    saw someone tweet would rather diagnosed aid c...
#  2    davestroup dukeofdrinkswel lol purely social d...
#  3                shyt real field china regarding covid
#  4                                  china covid problem
#  ..                                                 ...
#  143               ha russian propaganda swimming covid
#  144  wow could work amp save baseball wild realignm...
#  145  karma undefeated israel health minister claim ...
#  146  racial stupidity actually work favor group mov...
#  147  genx knew would save world day little later an...
#
#                                user                Topic Sentiment Verdict
#  0    https://twitter.com/DougSloan     US_2022_Topic_16  Positive    Fake
#  1    https://twitter.com/DougSloan     US_2022_Topic_17   Neutral    Fake
#  2    https://twitter.com/DougSloan     US_2022_Topic_10  Positive    Fake
#  3    https://twitter.com/DougSloan     US_2022_Topic_12   Neutral    Fake
#  4    https://twitter.com/DougSloan     US_2022_Topic_11  Negative    Fake
#  ..                             ...                  ...       ...     ...
#  143  https://twitter.com/DougSloan   US_Circuit_Topic_4  Positive    Fake
#  144  https://twitter.com/DougSloan   US_Circuit_Topic_3  Positive    Fake
#  145  https://twitter.com/DougSloan  US_Circuit_Topic_10  Positive    Fake
#  146  https://twitter.com/DougSloan   US_Circuit_Topic_1  Negative    Fake
#  147  https://twitter.com/DougSloan     US_Start_Topic_4  Positive    Fake
#
#  [148 rows x 6 columns],
#                            date  \
#  0    2023-02-18 17:03:25+00:00
#  1    2023-02-17 17:42:54+00:00
#  2    2023-02-04 21:48:37+00:00
#  3    2023-02-04 21:32:32+00:00
#  4    2023-01-21 16:45:24+00:00
#  ..                         ...
#  827  2020-03-22 03:18:01+00:00
#  828  2020-03-21 02:25:45+00:00
#  829  2020-03-21 02:24:58+00:00
#  830  2020-03-19 01:46:21+00:00
#  831  2020-03-17 21:26:22+00:00
#
#                                         renderedContent  \
#  0    augefortrump gofishlynn screwedbydemsx actbrig...
#  1    augefortrump gofishlynn screwedbydemsx actbrig...
#  2    augefortrump gofishlynn actbrigitte wearing ma...
#  3    augefortrump gofishlynn actbrigitte social med...
#  4    repmtg two people new mexico died taking iverm...
#  ..                                                 ...
#  827  realcandaceo trump clown already watch try bla...
#  828  donaldjtrumpjr thank donald trump lie told jok...
#  829  donaldjtrumpjr realdonaldtrump thank donald tr...
#  830                richardepcar hoping covid blow soon
#  831  christinamariek voicesbybri sjmonster rontoye ...
#
#                                  user               Topic Sentiment Verdict
#  0    https://twitter.com/HajjiADavis    US_2022_Topic_13   Neutral    Fake
#  1    https://twitter.com/HajjiADavis    US_2022_Topic_13  Negative    Fake
#  2    https://twitter.com/HajjiADavis    US_2022_Topic_13  Positive    Fake
#  3    https://twitter.com/HajjiADavis    US_2022_Topic_13  Negative    Fake
#  4    https://twitter.com/HajjiADavis    US_2022_Topic_14  Negative    Fake
#  ..                               ...                 ...       ...     ...
#  827  https://twitter.com/HajjiADavis  US_Circuit_Topic_7  Negative    Fake
#  828  https://twitter.com/HajjiADavis    US_Start_Topic_4  Positive    Fake
#  829  https://twitter.com/HajjiADavis    US_Start_Topic_4  Positive    Fake
#  830  https://twitter.com/HajjiADavis    US_Start_Topic_7  Positive    Fake
#  831  https://twitter.com/HajjiADavis   US_Start_Topic_15  Positive    Fake
#
#  [832 rows x 6 columns],
#  Empty DataFrame
#  Columns: [date, renderedContent, user, Topic, Sentiment, Verdict]
#  Index: [],
#                           date  \
#  0   2023-02-28 23:56:06+00:00
#  1   2023-02-28 23:11:05+00:00
#  2   2023-02-28 19:56:02+00:00
#  3   2023-02-28 19:36:02+00:00
#  4   2023-02-28 17:52:47+00:00
#  5   2023-02-28 17:46:06+00:00
#  6   2023-02-28 15:16:08+00:00
#  7   2023-02-28 14:51:04+00:00
#  8   2023-02-28 12:51:02+00:00
#  9   2023-02-28 10:06:07+00:00
#  10  2023-02-28 09:46:04+00:00
#  11  2023-02-28 07:06:05+00:00
#  12  2023-02-28 06:46:04+00:00
#  13  2023-02-28 01:36:06+00:00
#  14  2023-02-27 23:46:04+00:00
#  15  2023-02-27 21:51:07+00:00
#  16  2023-02-27 21:06:08+00:00
#  17  2023-02-27 15:29:15+00:00
#  18  2023-02-27 14:56:04+00:00
#  19  2023-02-27 14:46:07+00:00
#
#                                        renderedContent  \
#  0   john barrasso want congress debriefed energy d...
#  1              final answer origin remains reach http
#  2   china say open transparent covid origin tracin...
#  3    u ambassador china need honest origin covid http
#  4   birx u enough prevent another pandemic like co...
#  5               five takeaway big lab leak story http
#  6   new poll think covid came chinese lab occurred...
#  7               five takeaway big lab leak story http
#  8           new five takeaway big lab leak story http
#  9   rand paul call declassifying document showing ...
#  10  covid origin report reignites firestorm lab le...
#  11  rand paul call declassifying document showing ...
#  12  covid origin report reignites firestorm lab le...
#  13  white house covid lab leak theory definitive c...
#  14  new covid origin report reignites firestorm la...
#  15  state department biden senior official repeate...
#  16  white house covid lab leak theory definitive c...
#  17  rand paul call declassifying document showing ...
#  18  energy department concludes lab leak likely sp...
#  19  democrat entirely surprised energy covid lab l...
#
#                             user             Topic Sentiment Verdict
#  0   https://twitter.com/thehill  US_2022_Topic_16  Positive    Fake
#  1   https://twitter.com/thehill  US_2022_Topic_12  Positive    Fake
#  2   https://twitter.com/thehill  US_2022_Topic_12   Neutral    Fake
#  3   https://twitter.com/thehill   US_2022_Topic_9  Positive    Fake
#  4   https://twitter.com/thehill  US_2022_Topic_10  Positive    Fake
#  5   https://twitter.com/thehill  US_2022_Topic_11  Negative    Fake
#  6   https://twitter.com/thehill  US_2022_Topic_16   Neutral    Fake
#  7   https://twitter.com/thehill  US_2022_Topic_11  Negative    Fake
#  8   https://twitter.com/thehill  US_2022_Topic_11  Negative    Fake
#  9   https://twitter.com/thehill   US_2022_Topic_9   Neutral    Fake
#  10  https://twitter.com/thehill   US_2022_Topic_9  Negative    Fake
#  11  https://twitter.com/thehill   US_2022_Topic_9   Neutral    Fake
#  12  https://twitter.com/thehill   US_2022_Topic_9  Negative    Fake
#  13  https://twitter.com/thehill  US_2022_Topic_12  Negative    Fake
#  14  https://twitter.com/thehill   US_2022_Topic_9  Negative    Fake
#  15  https://twitter.com/thehill   US_2022_Topic_2   Neutral    Fake
#  16  https://twitter.com/thehill  US_2022_Topic_12  Negative    Fake
#  17  https://twitter.com/thehill   US_2022_Topic_9   Neutral    Fake
#  18  https://twitter.com/thehill   US_2022_Topic_7  Negative    Fake
#  19  https://twitter.com/thehill   US_2022_Topic_2  Positive    Fake  ]
