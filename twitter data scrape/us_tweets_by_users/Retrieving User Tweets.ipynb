# %%
import pandas as pd

# CSV File can be downloaded using the below link:
# US - https://smu-my.sharepoint.com/:x:/g/personal/dvhanley_2019_scis_smu_edu_sg/ETBsdzrVdcVGiAGx83SOdcABl_cnaeN07-I0Hs5GVDvHog?e=EynHn6

tweets_df = pd.read_csv("washington_tweets.csv")
tweets_df.head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_596\2937531015.py:3: DtypeWarning: Columns (28) have mixed types. Specify dtype option on import or set low_memory=False.
#   tweets_df = pd.read_csv("washington_tweets.csv")
#                                                  url  \
# 0  https://twitter.com/dcexaminer/status/16307191...
# 1  https://twitter.com/layla_abouzaid/status/1630...
# 2  https://twitter.com/foxnewspolitics/status/163...
# 3  https://twitter.com/thehill/status/16307185169...
# 4  https://twitter.com/NewsPolitics/status/163071...
#
#                         date  \
# 0  2023-02-28 23:58:49+00:00
# 1  2023-02-28 23:58:18+00:00
# 2  2023-02-28 23:56:27+00:00
# 3  2023-02-28 23:56:06+00:00
# 4  2023-02-28 23:55:58+00:00
#
#                                           rawContent  \
# 0  Newsom ends California COVID-19 state of emerg...
# 1  Question why everybody was making fun of many ...
# 2  FBI director says COVID pandemic 'most likely'...
# ...

# %%
# df_new = tweets_df[['date', 'renderedContent', 'user']]
# df_new.head()
# tweets_df = pd.read_csv("../coronavirus_newyork_tweets.csv")
# tweets_df
x = tweets_df[tweets_df["user"]=="https://twitter.com/realDonaldTrump"]
x
# Out:
# Empty DataFrame
# Columns: [url, date, rawContent, renderedContent, id, user, replyCount, retweetCount, likeCount, quoteCount, conversationId, lang, source, sourceUrl, sourceLabel, links, media, retweetedTweet, quotedTweet, inReplyToTweetId, inReplyToUser, mentionedUsers, coordinates, place, hashtags, cashtags, card, viewCount, vibe]
# Index: []
#
# [0 rows x 29 columns]

# %%
# for Quote Network

userlist = ['https://twitter.com/MayorBowser',
            'https://twitter.com/thehill',
            'https://twitter.com/atrupar',
            'https://twitter.com/CNN',
            'https://twitter.com/Heerak4Congress',
            'https://twitter.com/thehill', 
            'https://twitter.com/Dsquared75', 
            'https://twitter.com/washingtonpost',
            'https://twitter.com/realDonaldTrump',
            'https://twitter.com/gtconway3d'
           ]
for user in userlist:
    username = user.split('/')[-1]
    user_tweets = df_new[tweets_df['user'] == user]
    
    user_tweets.to_csv(f'{username}_tweets.csv', index=False)
    user_tweets.to_csv(f'{username}_tweets.txt', index=False, sep='\t')

# %%
# for Reply Network

userlist = ['https://twitter.com/realDonaldTrump',
            'https://twitter.com/thehill',
            'https://twitter.com/HajjiADavis',
            'https://twitter.com/diasporaonline',
            'https://twitter.com/aeidinge4',
            'https://twitter.com/DougSloan',
            'https://twitter.com/Aly_Dar8']
for user in userlist:
    username = user.split('/')[-1]
    user_tweets = df_new[df_new['user'] == user]
    
    user_tweets.to_csv(f'{username}_tweets.csv', index=False)
    user_tweets.to_csv(f'{username}_tweets.txt', index=False, sep='\t')

# %%
# QUOTE
tweets_df = pd.read_csv("washington_tweets.csv")
# tweets_df.iloc[1]["quotedTweet"]
quoted_orginal_tweet = []
for i in range(len(tweets_df)):
    if type(tweets_df.iloc[i]["inReplyToUser"]) == str and (tweets_df.iloc[i]["user"].split("/")[3] == 'atrupar'):
#         print(tweets_df.iloc[i]["inReplyToUser"])
        quoted_orginal_tweet.append(tweets_df.iloc[i]["conversationId"])
quoted_orginal_tweet
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_596\1963920047.py:2: DtypeWarning: Columns (28) have mixed types. Specify dtype option on import or set low_memory=False.
#   tweets_df = pd.read_csv("washington_tweets.csv")
# [1259263644358987776,
#  1280555038365057026,
#  1265381045978968064,
#  1261010395118043136,
#  1258475379775307776,
#  1249381812838825985,
#  1247863649785479169,
#  1245202676041867268,
#  1242483167807799296,
#  1241369935240200194,
#  1240976524876165122,
#  1240968033046335489,
#  1239939454976036864,
#  1239956968812490752,
#  1236831737478615042]

# %%
trump = []
for original_tweet in quoted_orginal_tweet:
    if original_tweet.split("/")[3] == "aeidinger":
        trump.append(original_tweet)
trump
# Out:
# ['https://twitter.com/aeidinger',
#  'https://twitter.com/aeidinger',
#  'https://twitter.com/aeidinger',
#  'https://twitter.com/aeidinger',
#  'https://twitter.com/aeidinger']

# %%
# df = pd.DataFrame(trump)
# df.to_csv('trump_quoted_tweets.csv')
# trump

# %%
import tweepy
import pandas as pd

# Set API keys 
consumer_key = 'hyOesruXLS3xYd4Rr7YKgqcrq'
consumer_secret = 'etZ9jpPlsbzp1sluNcj4SB7JEZC57qdDj7qGOhMkxMhJKemaIL'
access_token = '925626103024119809-Gm2YthgSX7Qrxgw8bjxuIcbIycE3nPg'
access_token_secret = 'nGRBBlix16xKWJqIBj6ZUdFrCrJmSD9QY7zp73fSMJaGA'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret) 
api = tweepy.Client(bearer_token="AAAAAAAAAAAAAAAAAAAAAAHnaAEAAAAA22oJikxYKiiQc2nVv3AgU%2BYP0y8%3DKzQviAuh1Ve4RtEIDcS5OXymFhTmgmEl2pIwSGqehWXGDcBMbT")

# %%
# tweet_content_arr = []
# for tweet in trump:
#     tweet_id = tweet.split("/")[-1]
#     tweet_data = api.get_tweet(tweet_id)
#     tweet_content = tweet_data.data.text
#     tweet_content_arr.append(tweet_content)

# ts = api.get_tweet(1337373146652020736)
# ts.data
# Out:
# <Tweet id=1337373146652020736 text='I just want to stop the world from killing itself!'>

# %%
import snscrape.modules.twitter as sntwitter
tweets_list = []
for tweet_id in quoted_orginal_tweet:
#     tweet_id = tweet.split("/")[-1]
#     print(tweet_id)
    for tweet_data in enumerate(sntwitter.TwitterTweetScraper(tweetId=tweet_id).get_items()): 
#         print(tweet_data)
#         print(tweet_data[1].date, tweet_data[1].renderedContent, tweet_data[1].user)
        if not hasattr(tweet_data[1], 'date'):
            continue
        else:
            tweets_list.append([tweet_data[1].date, tweet_data[1].renderedContent, tweet_data[1].user])
        
tweets_list
# Out:
# [[datetime.datetime(2020, 5, 9, 23, 27, 3, tzinfo=datetime.timezone.utc),
#   'Why did you choose those countries and not Britain and/or Spain and or France?',
# ...

# %%
# Out:
# []

# %%
tweets_df1 = pd.DataFrame(tweets_list, columns=['date','renderedContent','user'])
tweets_df1.to_csv("atrupar_tweets.csv", index=False)
