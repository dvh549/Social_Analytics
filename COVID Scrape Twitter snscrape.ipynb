# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd
import csv

# %% [markdown]
# Reference this: https://github.com/igorbrigadir/twitter-advanced-search
#
# https://medium.com/swlh/how-to-scrape-tweets-by-location-in-python-using-snscrape-8c870fa6ec25

# %%
# # Creating list to append tweet data 
# tweets_list1 = []

# # Using TwitterSearchScraper to scrape data and append tweets to list
# handle = 'sporeMOH'

# # declare a username 
# for i, tweet in enumerate(sntwitter.TwitterSearchScraper('from:' + handle).get_items()): 
#     if i > 3000: #number of tweets you want to scrape
#         break
        
#     #declare the attributes to be returned
#     tweets_list1.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
    
# # Creating a dataframe from the tweets list above 
# tweets_df1 = pd.DataFrame(tweets_list1, columns=['Datetime', 'Tweet Id', 'Text', 'Username'])

# %%
# Creating list to append tweet data 
tweets_list = []

# query = 'covid since:2020-01-01 until:2020-03-01 lang:en near:"Singapore"'
query = 'covid since:2019-10-01 until:2023-03-01 lang:en near:"Singapore"'

# declare a username 
for i, tweet in enumerate(sntwitter.TwitterSearchScraper(query).get_items()): 
    if i >= 100000: #number of tweets you want to scrape
        break
        
    #declare the attributes to be returned
    tweets_list.append([tweet.url, tweet.date, tweet.rawContent, 
                        tweet.renderedContent, tweet.id, tweet.user, 
                        tweet.replyCount, tweet.retweetCount, tweet.likeCount, 
                        tweet.quoteCount, tweet.conversationId, tweet.lang, 
                        tweet.source, tweet.sourceUrl, tweet.sourceLabel, 
                        tweet.links, tweet.media, tweet.retweetedTweet, 
                        tweet.quotedTweet, tweet.inReplyToTweetId, tweet.inReplyToUser, 
                        tweet.mentionedUsers, tweet.coordinates, tweet.place, tweet.hashtags, 
                        tweet.cashtags, tweet.card, tweet.viewCount, tweet.vibe])
    
# Creating a dataframe from the tweets list above 
tweets_df1 = pd.DataFrame(tweets_list, columns=['url', 'date', 'rawContent', 'renderedContent', 'id', 'user',
       'replyCount', 'retweetCount', 'likeCount', 'quoteCount',
       'conversationId', 'lang', 'source', 'sourceUrl', 'sourceLabel', 'links',
       'media', 'retweetedTweet', 'quotedTweet', 'inReplyToTweetId',
       'inReplyToUser', 'mentionedUsers', 'coordinates', 'place', 'hashtags',
       'cashtags', 'card', 'viewCount', 'vibe'])
# tweets_df1 = pd.DataFrame(tweets_list)

# %%
tweets_df1
# Out:
#                                                     url  \
# 0     https://twitter.com/khainad/status/16307166453...
# 1     https://twitter.com/MattHarrisEdD/status/16306...
# 2     https://twitter.com/Chindyagung1/status/163066...
# 3     https://twitter.com/mfame_guru/status/16306590...
# 4     https://twitter.com/mfame_guru/status/16306565...
# ...                                                 ...
# 9097  https://twitter.com/Dayreamer/status/122732253...
# 9098  https://twitter.com/crescenzo_mauro/status/122...
# 9099  https://twitter.com/PRO_FITS/status/1227254129...
# 9100  https://twitter.com/reubern_j_k/status/1227253...
# 9101  https://twitter.com/honorharger/status/1227249...
#
#                           date  \
# 0    2023-02-28 23:48:40+00:00
# 1    2023-02-28 22:30:03+00:00
# 2    2023-02-28 20:33:20+00:00
# 3    2023-02-28 19:59:48+00:00
# 4    2023-02-28 19:50:00+00:00
# ...                        ...
# 9097 2020-02-11 20:04:28+00:00
# ...

# %%
tweets_df1.to_csv("covid_singapore_tweets.csv", index=False)
