# %%
import pandas as pd
import os
import pickle

import preprocessor as p
import re
import contractions
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()

import gensim
from gensim.utils import simple_preprocess
import gensim.corpora as corpora
from gensim.test.utils import datapath

# %%
quote_csv = [f"Quote_Network/{file}" for file in os.listdir("Quote_Network") if file.endswith(".csv")]
reply_csv = [f"Reply_Network/{file}" for file in os.listdir("Reply_Network") if file.endswith(".csv")]

# %%
lemmatizer = WordNetLemmatizer()

def lemmatize_words(text):
    return " ".join([lemmatizer.lemmatize(word) for word in text])

def clean_tweet(tweet, column):
    ## remove contractions
    tweet[column] = tweet[column].apply(lambda x: [contractions.fix(word) for word in x.split()])

    ## convert back into string so that tokenization can be done
    tweet[column] = [' '.join(map(str, l)) for l in tweet[column]]

    ## tokenize
    tweet[column] = tweet[column].apply(word_tokenize)

    ## convert tokens to lowercase
    tweet[column] = tweet[column].apply(lambda x: [word.lower() for word in x])

    ## remove punctuations and numerics
    tweet[column] = tweet[column].apply(lambda x: [word for word in x if re.search('^[a-z]+$',word)])

    ## remove stopwords
    stop_list = stopwords.words('english')
    tweet[column] = tweet[column].apply(lambda x: [word for word in x if word not in stop_list])
    
    tweet[column] = tweet[column].apply(lambda x: lemmatize_words(x))
    return tweet

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

# %%
def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]

# %%
def check_topic(date, text):
    if date < '2020-04-01':
        lda_model = gensim.models.ldamodel.LdaModel.load(datapath("sg_start_lda_model_18"))
        dictionary = corpora.Dictionary.load(datapath("sg_start_lda_model_18.id2word"))
        num_topics = 18
        prefix = "SG_Start_Topic_"
    elif date >= '2020-04-01' and date < '2020-06-01':
        lda_model = gensim.models.ldamodel.LdaModel.load(datapath("sg_circuit_lda_model_17"))
        dictionary = corpora.Dictionary.load(datapath("sg_circuit_lda_model_17.id2word"))
        num_topics = 17
        prefix = "SG_Circuit_Topic_"
    elif date >= '2020-06-01' and date < '2021-12-01':
        lda_model = gensim.models.ldamodel.LdaModel.load(datapath("sg_phases_lda_model_11"))
        dictionary = corpora.Dictionary.load(datapath("sg_phases_lda_model_11.id2word"))
        num_topics = 11
        prefix = "SG_Phases_Topic_"
    elif date >= '2021-12-01' and date < '2023-02-01':
        lda_model = gensim.models.ldamodel.LdaModel.load(datapath("sg_acute_lda_model_18"))
        dictionary = corpora.Dictionary.load(datapath("sg_acute_lda_model_18.id2word"))
        num_topics = 18
        prefix = "SG_Acute_Topic_"
    else:
        lda_model = gensim.models.ldamodel.LdaModel.load(datapath("sg_green_lda_model_6"))
        dictionary = corpora.Dictionary.load(datapath("sg_green_lda_model_6.id2word"))
        num_topics = 6
        prefix = "SG_Green_Topic_"
        
    corpus = dictionary.doc2bow(text)
    top_topics = lda_model.get_document_topics(corpus, minimum_probability=0.0)
    topic_vec = [top_topics[i][1] for i in range(num_topics)]
    return f"{prefix}{topic_vec.index(max(topic_vec))+1}"

# %%
def determine_sentiment(score):
    if score < 0:
        return "Negative"
    elif score > 0:
        return "Positive"
    else:
        return "Neutral"

# %%
def preprocess(text):
    text = p.clean(text)
    tokenization = word_tokenize(text) 
    stop_words = set(stopwords.words('english'))
    tokenization = [w for w in tokenization if not w in stop_words]   
    return text

# %%
def fake_or_real(pred):
    if pred == 0:
        return "Real"
    else:
        return "Fake"

# %%
def load_vectorizer_and_model():
    return pickle.load(open("../../models/misinformation/vectorizer.txt", "rb")), pickle.load(open("../../models/misinformation/logreg.txt", "rb"))

# %%
vectorizer, model = load_vectorizer_and_model()
# Out:
# C:\Users\Wei Xuan\AppData\Local\Temp\ipykernel_41824\1737995115.py:2: DeprecationWarning: Please use `csr_matrix` from the `scipy.sparse` namespace, the `scipy.sparse.csr` namespace is deprecated.
#   return pickle.load(open("../../models/misinformation/vectorizer.txt", "rb")), pickle.load(open("../../models/misinformation/logreg.txt", "rb"))
# C:\anaconda3\lib\site-packages\sklearn\base.py:299: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.1.2 when using version 1.2.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# C:\anaconda3\lib\site-packages\sklearn\base.py:299: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.1.2 when using version 1.2.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# C:\anaconda3\lib\site-packages\sklearn\base.py:299: UserWarning: Trying to unpickle estimator LogisticRegression from version 1.1.2 when using version 1.2.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
modded_quote_dfs = []

for csv in quote_csv:
    df = pd.read_csv(csv)
    df2 = df.copy()
    df2 = clean_tweet(df, 'renderedContent')
    
    # Retrieve topics
    data = df2['renderedContent'].values.tolist()
    data_words = list(sent_to_words(data))
    # Build the bigram and trigram models
    bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
    trigram = gensim.models.Phrases(bigram[data_words], threshold=100)  
    # Faster way to get a sentence clubbed as a trigram/bigram
    bigram_mod = gensim.models.phrases.Phraser(bigram)
    trigram_mod = gensim.models.phrases.Phraser(trigram)
    data_words_trigrams = make_trigrams(data_words)
    topics = []
    for i in range(len(df2)):
        topics.append(check_topic(df2.iloc[i].date, data_words_trigrams[i]))
    df["Topic"] = topics
    
    # Calculate sentiments
    df2["renderedContent"] = df2['renderedContent'].apply(lambda tweet:str(tweet))
    sentiment_scores = df2['renderedContent'].apply(sid.polarity_scores)
    sentiments = sentiment_scores.apply(lambda x: x["compound"])
    sentiment_label = sentiments.apply(determine_sentiment)
    df["Sentiment"] = sentiment_label
    
    # Check if real / fake news
    df["renderedContent"] = df["renderedContent"].apply(preprocess)
    verdict_labels = []
    for i in range(len(df)):
        vectorized_text = vectorizer.transform([df.iloc[i].renderedContent])
        verdict_labels.append(fake_or_real(model.predict(vectorized_text)[0]))
    df["Verdict"] = verdict_labels
    
    modded_quote_dfs.append(df)

# %%
i=1

for df in modded_quote_dfs:
    df.to_csv(f"{i}.csv")
    i+=1

# %%
modded_quote_dfs
# Out:
# [                        date  \
#  0  2022-07-15 02:11:56+00:00
#  1  2022-05-04 05:46:40+00:00
#  2  2021-06-07 13:56:03+00:00
#
#                                       renderedContent  \
#  0  important message com wojciechowski restart gl...
#  1  covid control local restriction relaxed opport...
#  2  million dos administered poland begin covid va...
#
#                                 user               Topic Sentiment Verdict
#  0  https://twitter.com/BogdziewiczM    SG_Acute_Topic_8  Negative    Fake
#  1  https://twitter.com/BogdziewiczM   SG_Acute_Topic_10  Positive    Fake
#  2  https://twitter.com/BogdziewiczM  SG_Phases_Topic_10  Positive    Fake  ,
#                             date  \
#  0     2023-02-27 18:56:15+00:00
#  1     2023-02-27 07:01:10+00:00
#  2     2023-02-26 23:21:06+00:00
#  3     2023-02-26 06:58:05+00:00
#  4     2023-02-24 10:54:33+00:00
#  ...                         ...
#  996   2022-08-01 11:28:17+00:00
#  997   2022-08-01 07:06:33+00:00
#  998   2022-08-01 06:58:35+00:00
#  999   2022-08-01 02:45:34+00:00
#  1000  2022-08-01 00:44:35+00:00
#
#                                          renderedContent  \
#  0               china must honest origin envoy say http
#  1     japan shionogi see pill reaping u billion annu...
#  2     u agency say likely emerged china lab leak rep...
#  3     gambling hub macao drop mask mandate location ...
#  4                     badly affected china village http
#  ...                                                 ...
#  996   daily aug per cent singapore resident vaccinat...
#  997   vaccination booster shot child aged year old r...
#  998   singapore resident caught mean herd immunity o...
#  999   macao reopen city infection detected nine day ...
#  1000    new zealand border fully open long closure http
#
#                                       user              Topic Sentiment Verdict
#  0     https://twitter.com/ChannelNewsAsia   SG_Green_Topic_5  Positive    Fake
#  1     https://twitter.com/ChannelNewsAsia   SG_Green_Topic_6  Positive    Fake
#  0   https://twitter.com/DTrain    SG_Acute_Topic_16   Neutral    Fake
#  1   https://twitter.com/DTrain     SG_Acute_Topic_6  Positive    Fake
#  2   https://twitter.com/DTrain    SG_Acute_Topic_14  Positive    Fake
#  3   https://twitter.com/DTrain     SG_Acute_Topic_6   Neutral    Fake
#  4   https://twitter.com/DTrain    SG_Acute_Topic_13  Negative    Fake
#  5   https://twitter.com/DTrain    SG_Phases_Topic_1  Negative    Fake
#  6   https://twitter.com/DTrain    SG_Phases_Topic_1  Negative    Fake
#  7   https://twitter.com/DTrain    SG_Phases_Topic_3   Neutral    Fake
#  8   https://twitter.com/DTrain    SG_Phases_Topic_2  Negative    Fake
#  9   https://twitter.com/DTrain    SG_Phases_Topic_1   Neutral    Fake
#  10  https://twitter.com/DTrain    SG_Phases_Topic_7  Positive    Fake
#  11  https://twitter.com/DTrain    SG_Phases_Topic_1   Neutral    Real
#  12  https://twitter.com/DTrain    SG_Phases_Topic_3  Negative    Fake
#  13  https://twitter.com/DTrain    SG_Phases_Topic_1  Positive    Fake
#  14  https://twitter.com/DTrain    SG_Phases_Topic_1  Positive    Fake
#  15  https://twitter.com/DTrain   SG_Phases_Topic_10   Neutral    Fake
#  16  https://twitter.com/DTrain    SG_Phases_Topic_8  Positive    Fake
#  17  https://twitter.com/DTrain   SG_Phases_Topic_10  Negative    Fake
#  18  https://twitter.com/DTrain    SG_Phases_Topic_8  Positive    Fake
#  19  https://twitter.com/DTrain    SG_Phases_Topic_9   Neutral    Fake
#  20  https://twitter.com/DTrain    SG_Phases_Topic_1  Positive    Fake
#  21  https://twitter.com/DTrain    SG_Phases_Topic_8  Negative    Fake
#  22  https://twitter.com/DTrain    SG_Phases_Topic_8  Positive    Fake
#  23  https://twitter.com/DTrain  SG_Circuit_Topic_10  Negative    Fake
#  24  https://twitter.com/DTrain  SG_Circuit_Topic_14  Negative    Fake
#  25  https://twitter.com/DTrain  SG_Circuit_Topic_17   Neutral    Fake
#  26  https://twitter.com/DTrain   SG_Circuit_Topic_4  Negative    Fake
#  27  https://twitter.com/DTrain  SG_Circuit_Topic_15  Negative    Fake
#  28  https://twitter.com/DTrain     SG_Start_Topic_6  Negative    Fake
#  29  https://twitter.com/DTrain     SG_Start_Topic_6   Neutral    Fake
#  30  https://twitter.com/DTrain    SG_Start_Topic_15   Neutral    Fake
#  31  https://twitter.com/DTrain    SG_Start_Topic_17  Negative    Fake
#  32  https://twitter.com/DTrain    SG_Start_Topic_17   Neutral    Fake
#  33  https://twitter.com/DTrain     SG_Start_Topic_1   Neutral    Fake
#  34  https://twitter.com/DTrain    SG_Start_Topic_12  Negative    Fake
#  35  https://twitter.com/DTrain     SG_Start_Topic_4  Negative    Fake
#  36  https://twitter.com/DTrain     SG_Start_Topic_8  Negative    Fake
#  37  https://twitter.com/DTrain     SG_Start_Topic_4   Neutral    Fake
#  38  https://twitter.com/DTrain    SG_Start_Topic_16  Negative    Fake
#  39  https://twitter.com/DTrain    SG_Start_Topic_14  Positive    Fake
#  40  https://twitter.com/DTrain    SG_Start_Topic_13  Negative    Fake
#  1           sia named airline year strong recovery http
#  2     man china fly covid booster shot instead hong ...
#  3     doctor decide number day medical leave endemic...
#  4       recidivism rate stayed amp stable year sps http
#  ...                                                 ...
#  996   death august arose infection earlier month ong...
#  997                              new case unlinked http
#  998   update august new case case imported case tota...
#  999       minister jailed year aid corruption case http
#  1000  case linked north coast lodge cluster testing ...
#
#                                    user               Topic Sentiment Verdict
#  0     https://twitter.com/MothershipSG    SG_Green_Topic_5  Negative    Fake
#  1     https://twitter.com/MothershipSG    SG_Green_Topic_2  Positive    Fake
#  2     https://twitter.com/MothershipSG    SG_Green_Topic_5   Neutral    Fake
#  3     https://twitter.com/MothershipSG    SG_Green_Topic_3  Positive    Fake
#  4     https://twitter.com/MothershipSG    SG_Green_Topic_4  Positive    Real
#  ...                                ...                 ...       ...     ...
#  996   https://twitter.com/MothershipSG   SG_Phases_Topic_4  Negative    Fake
#  997   https://twitter.com/MothershipSG  SG_Phases_Topic_10   Neutral    Real
#  998   https://twitter.com/MothershipSG  SG_Phases_Topic_10   Neutral    Real
#  999   https://twitter.com/MothershipSG  SG_Phases_Topic_10  Negative    Fake
#  1000  https://twitter.com/MothershipSG  SG_Phases_Topic_10   Neutral    Real
#
#  [1001 rows x 6 columns],
#                            date  \
#  0    2023-02-26 10:10:35+00:00
#  1    2023-02-17 04:22:36+00:00
#  2    2023-02-15 04:00:19+00:00
#  3    2023-02-15 03:58:51+00:00
#  4    2023-02-14 13:42:14+00:00
#  ..                         ...
#  571  2020-07-28 04:50:24+00:00
#  572  2020-07-27 17:23:28+00:00
#  573  2021-08-05 07:55:39+00:00
#  574  2021-07-15 08:23:38+00:00
#  575  2021-07-05 10:48:58+00:00
#
#                                         renderedContent  \
#  0    lockdown conspiracy seriously know beneficial ...
#  1    apple paid celebrity endorse celebrate pfizer ...
#  2    conspiracy theory made pap covid expected poli...
#  3    conspiracy theory made pap covid simply falseh...
#  4       critical race theory viral covid stop nonsense
#  ..                                                 ...
#  571  father get today self employed bracket earn le...
#  572  oppositon supporter dissed singapore covid res...
#  573  thought cold allergy girlfriend insisted get c...
#  574  new local coronavirus case confirmed thursday ...
#  575  jakarta indonesia reported monday jul record n...
#
#                                     user               Topic Sentiment Verdict
#  0    https://twitter.com/temptempholder    SG_Green_Topic_2  Negative    Fake
#  1    https://twitter.com/temptempholder    SG_Green_Topic_1  Negative    Fake
#  2    https://twitter.com/temptempholder    SG_Green_Topic_1  Negative    Fake
#  3    https://twitter.com/temptempholder    SG_Green_Topic_4  Negative    Fake
#  4    https://twitter.com/temptempholder    SG_Green_Topic_2  Negative    Fake
#  ..                                  ...                 ...       ...     ...
#  571  https://twitter.com/temptempholder   SG_Phases_Topic_2  Positive    Fake
#  572  https://twitter.com/temptempholder  SG_Phases_Topic_10  Positive    Fake
#  573  https://twitter.com/temptempholder  SG_Phases_Topic_11  Positive    Fake
#  574  https://twitter.com/temptempholder  SG_Phases_Topic_10  Positive    Real
#  575  https://twitter.com/temptempholder   SG_Phases_Topic_1  Negative    Real
#
#  [576 rows x 6 columns],
#                           date  \
#  37  https://twitter.com/theforceawaken   SG_Phases_Topic_1  Positive    Fake
#  38  https://twitter.com/theforceawaken   SG_Phases_Topic_3   Neutral    Fake
#  39  https://twitter.com/theforceawaken  SG_Circuit_Topic_2  Negative    Fake  ]

# %%
modded_reply_dfs = []

for csv in reply_csv:
    df = pd.read_csv(csv)
    df2 = df.copy()
    df2 = clean_tweet(df, 'renderedContent')
    
    # Retrieve topics
    data = df2['renderedContent'].values.tolist()
    data_words = list(sent_to_words(data))
    # Build the bigram and trigram models
    bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
    trigram = gensim.models.Phrases(bigram[data_words], threshold=100)  
    # Faster way to get a sentence clubbed as a trigram/bigram
    bigram_mod = gensim.models.phrases.Phraser(bigram)
    trigram_mod = gensim.models.phrases.Phraser(trigram)
    data_words_trigrams = make_trigrams(data_words)
    topics = []
    for i in range(len(df2)):
        topics.append(check_topic(df2.iloc[i].date, data_words_trigrams[i]))
    df["Topic"] = topics
    
    # Calculate sentiments
    df2["renderedContent"] = df2['renderedContent'].apply(lambda tweet:str(tweet))
    sentiment_scores = df2['renderedContent'].apply(sid.polarity_scores)
    sentiments = sentiment_scores.apply(lambda x: x["compound"])
    sentiment_label = sentiments.apply(determine_sentiment)
    df["Sentiment"] = sentiment_label
    
    # Check if real / fake news
    df["renderedContent"] = df["renderedContent"].apply(preprocess)
    verdict_labels = []
    for i in range(len(df)):
        vectorized_text = vectorizer.transform([df.iloc[i].renderedContent])
        verdict_labels.append(fake_or_real(model.predict(vectorized_text)[0]))
    df["Verdict"] = verdict_labels
    
    modded_reply_dfs.append(df)

# %%
i=1

for df in modded_reply_dfs:
    df.to_csv(f"Reply_{i}.csv")
    i+=1

# %%
modded_reply_dfs
# Out:
# [                         date  \
#  0   2023-01-24 04:59:39+00:00
#  1   2022-12-24 16:48:10+00:00
#  2   2022-12-12 15:58:10+00:00
#  3   2022-11-29 17:21:37+00:00
#  4   2022-11-29 15:59:54+00:00
#  ..                        ...
#  74  2022-02-23 09:35:35+00:00
#  75  2022-02-19 05:38:09+00:00
#  76  2022-02-13 19:56:05+00:00
#  77  2022-02-13 19:34:24+00:00
#  78  2022-02-05 00:38:28+00:00
#
#                                        renderedContent  \
#  0   patience skill talent arrived china feel covid...
#  1                   first wave people recovered covid
#  2   think people sick covid people know beijing co...
#  3   amfchina change want see xi stupid covid polic...
#  4   come man much chinese people hate covid policy...
#  ..                                                ...
#  74  thecyrusjanssen vanderbiltu place look dirty s...
#  75  read article evidence anything supposition ton...
#  76  heard friend hk lot going china said ok quaran...
#  77  beer go much better amp problem solved pre cov...
#  78  ejustificator koljakiller japan still ok work ...
#
#                                     user              Topic Sentiment Verdict
#  0   https://twitter.com/bobby_the_great  SG_Acute_Topic_17  Positive    Fake
#  1   https://twitter.com/bobby_the_great  SG_Acute_Topic_10   Neutral    Fake
#  2   https://twitter.com/bobby_the_great  SG_Acute_Topic_15  Negative    Fake
#  3   https://twitter.com/bobby_the_great   SG_Acute_Topic_5  Negative    Fake
#  4   https://twitter.com/bobby_the_great   SG_Acute_Topic_6  Negative    Fake
#  ..                                  ...                ...       ...     ...
#  74  https://twitter.com/bobby_the_great   SG_Acute_Topic_7  Negative    Fake
#  75  https://twitter.com/bobby_the_great   SG_Acute_Topic_9  Positive    Fake
#  76  https://twitter.com/bobby_the_great   SG_Acute_Topic_9  Positive    Fake
#  38  grabsg car sneeze driver scolded coz felt covi...
#  39  kittensarepink hope grab look fair paid bother...
#  40  joannasuyin claim release covid patient hospit...
#  41  gym seeing approx loss revenue due cleaner mba...
#  42  whole family self isolating obviously wait res...
#  43  one doctor one clinic assistant handle registr...
#  44  wish could proud jalan besar grc first grc led...
#  45  pandemic phase causing water bill increase coz...
#  46  racist singaporean woman angry fdw keep asking...
#  47  zeligdhilee actually understand let beautician...
#  48  six men one woman aged charged flouting rule r...
#  49  ofmeowandbake tanhuiyi furryphotos sir self em...
#  50  think people sign need realize fight going end...
#  51                new source coronavirus spread party
#  52  exhausting sweaty one worst thing ever experie...
#  53  psa week left file tax folk know still expects...
#  54  whatsapp fakenews message going around saying ...
#  55  canada prime minister justin trudeau wife soph...
#  56  livideye keep hearing privacy concern people s...
#  57  man lost permanent resident status banned sing...
#  58  got home crazy fun hotpot dinner bunch respons...
#  59  report outbreak idiocy spreading time faster c...
#
#                                user                Topic Sentiment Verdict
#  0   https://twitter.com/daphnemaia     SG_Acute_Topic_9  Negative    Real
#  1   https://twitter.com/daphnemaia    SG_Acute_Topic_17  Negative    Fake
#  2   https://twitter.com/daphnemaia     SG_Acute_Topic_2   Neutral    Fake
#  3   https://twitter.com/daphnemaia     SG_Acute_Topic_2  Negative    Fake
#  4   https://twitter.com/daphnemaia    SG_Acute_Topic_17  Positive    Fake
#  5   https://twitter.com/daphnemaia    SG_Acute_Topic_17  Negative    Fake
#  6   https://twitter.com/daphnemaia     SG_Acute_Topic_9  Positive    Fake
#  7   https://twitter.com/daphnemaia     SG_Acute_Topic_9  Negative    Fake
#  8   https://twitter.com/daphnemaia    SG_Acute_Topic_12  Positive    Fake
#  9   https://twitter.com/daphnemaia     SG_Acute_Topic_9  Positive    Real
#  10  https://twitter.com/daphnemaia     SG_Acute_Topic_2  Negative    Fake
#  11  https://twitter.com/daphnemaia    SG_Acute_Topic_10  Positive    Fake
#  12  https://twitter.com/daphnemaia    SG_Acute_Topic_18  Positive    Fake
#  13  https://twitter.com/daphnemaia     SG_Acute_Topic_7  Positive    Real
#  14  https://twitter.com/daphnemaia    SG_Acute_Topic_17  Positive    Fake
#  15  https://twitter.com/daphnemaia     SG_Acute_Topic_8  Positive    Real
#  16  https://twitter.com/daphnemaia   SG_Phases_Topic_11  Positive    Fake
#  17  https://twitter.com/daphnemaia    SG_Phases_Topic_1  Negative    Fake
#  18  https://twitter.com/daphnemaia    SG_Phases_Topic_8  Negative    Fake
#  19  https://twitter.com/daphnemaia    SG_Phases_Topic_8  Positive    Fake
#  20  https://twitter.com/daphnemaia    SG_Phases_Topic_8  Negative    Fake
#  21  https://twitter.com/daphnemaia    SG_Phases_Topic_7  Negative    Fake
#  22  https://twitter.com/daphnemaia   SG_Phases_Topic_10  Positive    Fake
#  23  https://twitter.com/daphnemaia    SG_Phases_Topic_8  Positive    Fake
#  24  https://twitter.com/daphnemaia   SG_Phases_Topic_10  Positive    Fake
#  25  https://twitter.com/daphnemaia   SG_Phases_Topic_10  Positive    Fake
#  26  https://twitter.com/daphnemaia   SG_Phases_Topic_11  Positive    Fake
#  27  https://twitter.com/daphnemaia    SG_Phases_Topic_8  Positive    Fake
#  28  https://twitter.com/daphnemaia    SG_Phases_Topic_1  Positive    Fake
#  29  https://twitter.com/daphnemaia    SG_Phases_Topic_7  Positive    Fake
#  30  https://twitter.com/daphnemaia    SG_Phases_Topic_7   Neutral    Real
#  31  https://twitter.com/daphnemaia    SG_Phases_Topic_1  Negative    Fake
#  32  https://twitter.com/daphnemaia    SG_Phases_Topic_8  Negative    Fake
#  33  https://twitter.com/daphnemaia    SG_Phases_Topic_6  Negative    Fake
#  34  https://twitter.com/daphnemaia    SG_Phases_Topic_7  Negative    Fake
#  35  https://twitter.com/daphnemaia    SG_Phases_Topic_6  Negative    Real
#  36  https://twitter.com/daphnemaia    SG_Phases_Topic_2  Positive    Fake
#  37  https://twitter.com/daphnemaia    SG_Phases_Topic_2  Positive    Fake
#  38  https://twitter.com/daphnemaia    SG_Phases_Topic_3  Positive    Fake
#  39  https://twitter.com/daphnemaia    SG_Phases_Topic_3  Positive    Fake
#  40  https://twitter.com/daphnemaia    SG_Phases_Topic_1  Negative    Fake
#  41  https://twitter.com/daphnemaia    SG_Phases_Topic_1  Positive    Fake
#  42  https://twitter.com/daphnemaia    SG_Phases_Topic_8  Positive    Fake
#  43  https://twitter.com/daphnemaia   SG_Phases_Topic_10  Positive    Fake
#  44  https://twitter.com/daphnemaia    SG_Phases_Topic_4  Negative    Fake
#  45  https://twitter.com/daphnemaia    SG_Phases_Topic_9  Positive    Fake
#  46  https://twitter.com/daphnemaia    SG_Phases_Topic_8  Negative    Fake
#  47  https://twitter.com/daphnemaia    SG_Phases_Topic_1  Positive    Fake
#  48  https://twitter.com/daphnemaia  SG_Circuit_Topic_14  Negative    Fake
#  49  https://twitter.com/daphnemaia   SG_Circuit_Topic_1  Positive    Fake
#  50  https://twitter.com/daphnemaia  SG_Circuit_Topic_10  Negative    Real
#  51  https://twitter.com/daphnemaia   SG_Circuit_Topic_5  Positive    Fake
#  52  https://twitter.com/daphnemaia  SG_Circuit_Topic_14  Negative    Fake
#  53  https://twitter.com/daphnemaia  SG_Circuit_Topic_15   Neutral    Fake
#  54  https://twitter.com/daphnemaia    SG_Start_Topic_10  Negative    Fake
#  55  https://twitter.com/daphnemaia    SG_Start_Topic_14   Neutral    Fake
#  56  https://twitter.com/daphnemaia     SG_Start_Topic_8  Positive    Real
#  57  https://twitter.com/daphnemaia    SG_Start_Topic_15  Negative    Fake
#  58  https://twitter.com/daphnemaia     SG_Start_Topic_2  Positive    Fake
#  59  https://twitter.com/daphnemaia    SG_Start_Topic_15   Neutral    Fake  ,
#                             date  \
#  0     2023-02-24 11:44:55+00:00
#  1     2023-02-19 23:17:30+00:00
#  2     2023-02-19 10:45:56+00:00
#  3     2023-02-17 11:39:25+00:00
#  4     2023-02-16 12:53:42+00:00
#  ...                         ...
#  996   2022-02-08 06:21:54+00:00
#  997   2022-02-08 04:18:22+00:00
#  998   2022-02-08 01:27:13+00:00
#  999   2022-02-07 11:37:48+00:00
#  1000  2022-02-07 10:54:22+00:00
#
#                                          renderedContent  \
#  0     million passenger pas thru kuala lumpur intern...
#  1                              wishing best spm student
#  2          cosplay obvious reason giving yea understand
#  3                                        mp kepala bata
#  4     autism autoimmune disease cancer seems spend p...
#  ...                                                 ...
#  996   sabah report new case today breaching mark hig...
#  997   ngyahloon soon week case climb since hospitali...
#  998   reported death bid perak bid penang bid selang...
#  999   malaysia covid confirmed imp discharged icu ve...
#  1000   monday test number reporting usually lowest case
#
#                                      user              Topic Sentiment Verdict
#  0     https://twitter.com/malaysia_covid   SG_Green_Topic_3   Neutral    Fake
#  1     https://twitter.com/malaysia_covid   SG_Green_Topic_2  Positive    Fake
#  2     https://twitter.com/malaysia_covid   SG_Green_Topic_5  Positive    Fake
#  3     https://twitter.com/malaysia_covid   SG_Green_Topic_1   Neutral    Fake
#  4     https://twitter.com/malaysia_covid   SG_Green_Topic_6  Negative    Fake
#  ...                                  ...                ...       ...     ...
#  996   https://twitter.com/malaysia_covid  SG_Acute_Topic_13  Positive    Real
#  997   https://twitter.com/malaysia_covid  SG_Acute_Topic_13  Negative    Real
#  998   https://twitter.com/malaysia_covid  SG_Acute_Topic_13  Negative    Fake
#  999   https://twitter.com/malaysia_covid   SG_Acute_Topic_9   Neutral    Fake
#  1000  https://twitter.com/malaysia_covid  SG_Acute_Topic_16  Negative    Real
#
#  [1001 rows x 6 columns],
#                            date  \
#  0    2022-12-25 07:49:21+00:00
#  1    2022-11-11 03:37:10+00:00
#  2    2022-10-26 04:54:33+00:00
#  3    2022-10-09 07:16:10+00:00
#  4    2022-09-01 03:58:15+00:00
#  ..                         ...
#  258  2020-02-03 00:06:42+00:00
#  259  2020-02-02 12:30:04+00:00
#  260  2020-02-02 08:52:34+00:00
#  261  2020-02-01 04:56:58+00:00
#  262  2020-02-01 04:42:47+00:00
#
#                                         renderedContent  \
#  0    china many covid death wor people died severe ...
#  1    ernamh leave country without travel insurance ...
#  2    seventeen concert singapore october apparently...
#  3    jdeamattson zacroix many yearly one cover covi...
#  4    chinese national like join throng running mall...
#  ..                                                 ...
#  258  outrage italian conservatoire ban oriental stu...
#  259  best time dinner shop nex today boh lang boh q...
#  260  coronavirus cambodia refuse evacuate citizen c...
#  261  singapore home one busiest airport simisai wuh...
#  262  find get four mask gahmen link postal code rem...
#
#                              user              Topic Sentiment Verdict
#  0    https://twitter.com/mrbrown   SG_Acute_Topic_2  Negative    Fake
#  1    https://twitter.com/mrbrown   SG_Acute_Topic_6  Positive    Fake
#  2    https://twitter.com/mrbrown   SG_Acute_Topic_3  Positive    Fake
#  3    https://twitter.com/mrbrown  SG_Acute_Topic_10   Neutral    Fake
#  4    https://twitter.com/mrbrown  SG_Acute_Topic_17  Positive    Fake
#  ..                           ...                ...       ...     ...
#  258  https://twitter.com/mrbrown   SG_Start_Topic_6  Negative    Fake
#  259  https://twitter.com/mrbrown   SG_Start_Topic_5  Positive    Fake
#  260  https://twitter.com/mrbrown  SG_Start_Topic_16  Negative    Fake
#  261  https://twitter.com/mrbrown   SG_Start_Topic_8   Neutral    Fake
#  262  https://twitter.com/mrbrown  SG_Start_Topic_16  Negative    Fake
#
#  [263 rows x 6 columns],
#                            date  \
#  0    2023-02-11 06:07:29+00:00
#  1    2022-12-10 05:56:38+00:00
#  2    2022-11-23 05:43:46+00:00
#  3    2022-07-12 20:46:57+00:00
#  4    2022-07-11 09:16:41+00:00
#  ..                         ...
#  107  2020-04-02 05:32:44+00:00
#  108  2020-04-02 03:33:31+00:00
#  109  2020-03-31 00:15:30+00:00
#  110  2020-03-06 23:54:57+00:00
#  111  2020-03-04 10:18:27+00:00
#
#                                         renderedContent  \
#  0    flipoz sarakahmed kiwibronny bqdressler votefo...
#  1    nicolasnzl kitcatclaws yep keep night worrying...
#  2    juliefairey dialogue around long covid reminds...
#  3    gingereejit agujitayuppi annehelen shingle wor...
#  4    mincandescence megderonde charlottecooknz due ...
#  ..                                                 ...
#  107  bunch muppets new zealand police urge thief st...
#  108  siouxsiew argue science lot question class ask...
#  109  finding odd living multiple reality singapore ...
#  110  sjenkinsnz claireamosnz gsapartnership dianeca...
#  111  school closed singapore due still couple kid n...
#
#                                      user               Topic Sentiment Verdict
#  0    https://twitter.com/traintheteacher    SG_Green_Topic_2  Negative    Fake
#  1    https://twitter.com/traintheteacher    SG_Acute_Topic_8  Negative    Fake
#  2    https://twitter.com/traintheteacher    SG_Acute_Topic_5  Negative    Fake
#  3    https://twitter.com/traintheteacher    SG_Acute_Topic_3  Negative    Fake
#  4    https://twitter.com/traintheteacher    SG_Acute_Topic_2  Positive    Real
#  ..                                   ...                 ...       ...     ...
#  107  https://twitter.com/traintheteacher  SG_Circuit_Topic_9  Negative    Fake
#  108  https://twitter.com/traintheteacher  SG_Circuit_Topic_4  Negative    Fake
#  109  https://twitter.com/traintheteacher   SG_Start_Topic_12  Negative    Fake
#  110  https://twitter.com/traintheteacher    SG_Start_Topic_6  Positive    Fake
#  111  https://twitter.com/traintheteacher    SG_Start_Topic_6  Positive    Fake
#
#  [112 rows x 6 columns],
#                            date  \
#  0    2022-09-30 19:26:20+00:00
#  1    2022-09-24 01:31:49+00:00
#  2    2022-09-22 16:33:16+00:00
#  3    2022-09-22 05:17:08+00:00
#  4    2022-08-01 12:38:17+00:00
#  ..                         ...
#  879  2020-03-22 06:50:38+00:00
#  880  2020-03-21 12:46:30+00:00
#  881  2020-03-21 12:16:27+00:00
#  882  2020-03-18 07:46:45+00:00
#  883  2020-03-16 04:50:17+00:00
#
#                                         renderedContent  \
#  0                    daily case singapore increase moh
#  1    hong kong scrap hotel quarantine overseas arri...
#  2    singapore scientist develop blood test kit det...
#  3    moderna bivalent vaccine also creates antibody...
#  4    death added singapore official tally revision moh
#  ..                                                 ...
#  879           italy factor behind coronavirus disaster
#  880  moment company good friend privilege life thro...
#  881  freedom taken away left memory evening singapo...
#  882            life go normal despite coronavirus http
#  883         find everywhere singapore coronavirus http
#
#                                 user              Topic Sentiment Verdict
#  0    https://twitter.com/_rodahidup  SG_Acute_Topic_13  Positive    Real
#  1    https://twitter.com/_rodahidup   SG_Acute_Topic_9   Neutral    Fake
#  2    https://twitter.com/_rodahidup   SG_Acute_Topic_6   Neutral    Fake
#  3    https://twitter.com/_rodahidup   SG_Acute_Topic_4  Positive    Fake
#  4    https://twitter.com/_rodahidup  SG_Acute_Topic_15  Negative    Fake
#  ..                              ...                ...       ...     ...
#  879  https://twitter.com/_rodahidup   SG_Start_Topic_9  Negative    Fake
#  880  https://twitter.com/_rodahidup  SG_Start_Topic_12  Positive    Fake
#  881  https://twitter.com/_rodahidup   SG_Start_Topic_7  Positive    Fake
#  882  https://twitter.com/_rodahidup  SG_Start_Topic_12   Neutral    Fake
#  883  https://twitter.com/_rodahidup   SG_Start_Topic_7   Neutral    Fake
#
#  [884 rows x 6 columns]]
